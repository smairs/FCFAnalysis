# %% [markdown]
# # Beginning With Raw Calibrator Data: Derive the SCUBA-2 FCFs
#
# This notebook illustrates and summarises the compilation of some of the more important codes and testing I have been doing for the past few months whenever I have had time to address the SCUBA-2 FCF issue.
#
# Here is a basic summary:
#
# 1. Finding Physical Opacity Relations to Test
# 1. Finding the Optimal Opacity Relation for each wavelength out of that physical set
# 1. Measuring the Peak and Arcsec FCFs for each wavelength (all data)
# 1. Applying sensible constraints to the data and recognising different times of night/weather make differences
# 1. Looking at the data taken while the membrane was removed
# 1. Comparing the pre-membrane-removal and post-membrane-replacement data
# 1. Looking at other metrics such as beam size/shape

# %% [markdown]
# # Finding a set of physical opacity relations
#
# I extracted PWV versus Transmission data from the CSO interactive plotter and saved that information for each wavelength
#
# I then built two functions that, together, interpolate over that data and return a ZENITH transmission value for a given input tau225 (Part of a larger package called TauRelAnalysis.py which is in this working directory).
#
# `FitCSOTransvsPWV.py`: This code takes the tabular information from the CSO interactive plotter and constructs a Transmission versus PWV Function
#
# `CSOtrans.py`: This code takes an input tau225 value, converts it to a PWV using the relations:
#
# PWVzen = (tau225zen - 0.017) / 0.04 ----- From Dempsey et al. 2013
#
# and then uses the Transmission versus PWV Function to return a zenith transmission.
#
# Then, I built a function to generate physically likely opacity relations:
#
# `phystau.py`: You supply a range of "a" and "b" values to convert the tau225 values into tau345 (850 microns) and tau666 (450 microns):
#
# tauX = a(tau225 - b)
#
# Then, the code genrates a transmission for every combination of a and b value, tau225 value between 0.03 and 0.20 (you choose the step size), and airmass between 1.0 and 2.0 (you choose the step size).
#
# transmission = exp(-tauX x airmass)
#
# The code then compares this calculated transmission to the expected transmission for all (tau x airmass) values and all combinations of a and b (the proper airmass correction is made for the expected transmission from the CSO data). We can then determine which a and b combinations give us physical transmissions across all the weather bands we are interested in.
#
# The biggest time sink is the construction of the TRANSvsPWV function. I have recently been told that there are ways to access the ATM model that CASA uses with starlink - that might be worth a try as well.

# %%
#Ensure plots show up in the notebook

# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (9,9)

# %%
# Run phystau for both 450 and 850 microns and display a couple of examples:
from find_physical_tau_relations_clean import phystau

a450ST   = 19 
a450EN   = 30
a450step = 0.5

b450ST   = 0.006
b450EN   = 0.018
b450step = 0.002

a850ST   = 4.0 
a850EN   = 5.7
a850step = 0.1

b850ST   = 0.004
b850EN   = 0.015
b850step = 0.0002

param_num  = 100.0
physthresh = 0.05


phystau(a450ST,a450EN,a450step,b450ST,b450EN,b450step,450,physthresh,param_num)
phystau(a850ST,a850EN,a850step,b850ST,b850EN,b850step,850,physthresh,param_num)
# Out:
#  Working on Opacity Relation #1 out of 161
#
#
#  Working on Opacity Relation #2 out of 161
#
#
#  Working on Opacity Relation #3 out of 161
#
#
#  Working on Opacity Relation #4 out of 161
#
#
#  Working on Opacity Relation #5 out of 161
#
#
#  Working on Opacity Relation #6 out of 161
#
#
#  Working on Opacity Relation #7 out of 161
#
#
#  Working on Opacity Relation #8 out of 161
#
#
#  Working on Opacity Relation #9 out of 161
#
#
#  Working on Opacity Relation #10 out of 161
#
#
#  Working on Opacity Relation #11 out of 161
#
#
#  Working on Opacity Relation #12 out of 161
#
#
#  Working on Opacity Relation #13 out of 161
#
#
#  Working on Opacity Relation #14 out of 161
#
#
#  Working on Opacity Relation #15 out of 161
#
#
#  Working on Opacity Relation #16 out of 161
#
#
#  Working on Opacity Relation #17 out of 161
#
#
#  Working on Opacity Relation #18 out of 161
#
#
#  Working on Opacity Relation #19 out of 161
#
#
#  Working on Opacity Relation #20 out of 161
#
#
#  Working on Opacity Relation #21 out of 161
#
#
#  Working on Opacity Relation #22 out of 161
#
#
#  Working on Opacity Relation #23 out of 161
#
#
#  Working on Opacity Relation #24 out of 161
#
#
#  Working on Opacity Relation #25 out of 161
#
#
#  Working on Opacity Relation #26 out of 161
#
#
#  Working on Opacity Relation #27 out of 161
#
#
#  Working on Opacity Relation #28 out of 161
#
#
#  Working on Opacity Relation #29 out of 161
#
#
#  Working on Opacity Relation #30 out of 161
#
#
#  Working on Opacity Relation #31 out of 161
#
#
#  Working on Opacity Relation #32 out of 161
#
#
#  Working on Opacity Relation #33 out of 161
#
#
#  Working on Opacity Relation #34 out of 161
#
#
#  Working on Opacity Relation #35 out of 161
#
#
#  Working on Opacity Relation #36 out of 161
#
#
#  Working on Opacity Relation #37 out of 161
#
#
#  Working on Opacity Relation #38 out of 161
#
#
#  Working on Opacity Relation #39 out of 161
#
#
#  Working on Opacity Relation #40 out of 161
#
#
#  Working on Opacity Relation #41 out of 161
#
#
#  Working on Opacity Relation #42 out of 161
#
#
#  Working on Opacity Relation #43 out of 161
#
#
#  Working on Opacity Relation #44 out of 161
#
#
#  Working on Opacity Relation #45 out of 161
#
#
#  Working on Opacity Relation #46 out of 161
#
#
#  Working on Opacity Relation #47 out of 161
#
#
#  Working on Opacity Relation #48 out of 161
#
#
#  Working on Opacity Relation #49 out of 161
#
#
#  Working on Opacity Relation #50 out of 161
#
#
#  Working on Opacity Relation #51 out of 161
#
#
#  Working on Opacity Relation #52 out of 161
#
#
#  Working on Opacity Relation #53 out of 161
#
#
#  Working on Opacity Relation #54 out of 161
#
#
#  Working on Opacity Relation #55 out of 161
#
#
#  Working on Opacity Relation #56 out of 161
#
#
#  Working on Opacity Relation #57 out of 161
#
#
#  Working on Opacity Relation #58 out of 161
#
#
#  Working on Opacity Relation #59 out of 161
#
#
#  Working on Opacity Relation #60 out of 161
#
#
#  Working on Opacity Relation #61 out of 161
#
#
#  Working on Opacity Relation #62 out of 161
#
#
#  Working on Opacity Relation #63 out of 161
#
#
#  Working on Opacity Relation #64 out of 161
#
#
#  Working on Opacity Relation #65 out of 161
#
#
#  Working on Opacity Relation #66 out of 161
#
#
#  Working on Opacity Relation #67 out of 161
#
#
#  Working on Opacity Relation #68 out of 161
#
#
#  Working on Opacity Relation #69 out of 161
#
#
#  Working on Opacity Relation #70 out of 161
#
#
#  Working on Opacity Relation #71 out of 161
#
#
#  Working on Opacity Relation #72 out of 161
#
#
#  Working on Opacity Relation #73 out of 161
#
#
#  Working on Opacity Relation #74 out of 161
#
#
#  Working on Opacity Relation #75 out of 161
#
#
#  Working on Opacity Relation #76 out of 161
#
#
#  Working on Opacity Relation #77 out of 161
#
#
#  Working on Opacity Relation #78 out of 161
#
#
#  Working on Opacity Relation #79 out of 161
#
#
#  Working on Opacity Relation #80 out of 161
#
#
#  Working on Opacity Relation #81 out of 161
#
#
#  Working on Opacity Relation #82 out of 161
#
#
#  Working on Opacity Relation #83 out of 161
#
#
#  Working on Opacity Relation #84 out of 161
#
#
#  Working on Opacity Relation #85 out of 161
#
#
#  Working on Opacity Relation #86 out of 161
#
#
#  Working on Opacity Relation #87 out of 161
#
#
#  Working on Opacity Relation #88 out of 161
#
#
#  Working on Opacity Relation #89 out of 161
#
#
#  Working on Opacity Relation #90 out of 161
#
#
#  Working on Opacity Relation #91 out of 161
#
#
#  Working on Opacity Relation #92 out of 161
#
#
#  Working on Opacity Relation #93 out of 161
#
#
#  Working on Opacity Relation #94 out of 161
#
#
#  Working on Opacity Relation #95 out of 161
#
#
#  Working on Opacity Relation #96 out of 161
#
#
#  Working on Opacity Relation #97 out of 161
#
#
#  Working on Opacity Relation #98 out of 161
#
#
#  Working on Opacity Relation #99 out of 161
#
#
#  Working on Opacity Relation #100 out of 161
#
#
#  Working on Opacity Relation #101 out of 161
#
#
#  Working on Opacity Relation #102 out of 161
#
#
#  Working on Opacity Relation #103 out of 161
#
#
#  Working on Opacity Relation #104 out of 161
#
#
#  Working on Opacity Relation #105 out of 161
#
#
#  Working on Opacity Relation #106 out of 161
#
#
#  Working on Opacity Relation #107 out of 161
#
#
#  Working on Opacity Relation #108 out of 161
#
#
#  Working on Opacity Relation #109 out of 161
#
#
#  Working on Opacity Relation #110 out of 161
#
#
#  Working on Opacity Relation #111 out of 161
#
#
#  Working on Opacity Relation #112 out of 161
#
#
#  Working on Opacity Relation #113 out of 161
#
#
#  Working on Opacity Relation #114 out of 161
#
#
#  Working on Opacity Relation #115 out of 161
#
#
#  Working on Opacity Relation #116 out of 161
#
#
#  Working on Opacity Relation #117 out of 161
#
#
#  Working on Opacity Relation #118 out of 161
#
#
#  Working on Opacity Relation #119 out of 161
#
#
#  Working on Opacity Relation #120 out of 161
#
#
#  Working on Opacity Relation #121 out of 161
#
#
#  Working on Opacity Relation #122 out of 161
#
#
#  Working on Opacity Relation #123 out of 161
#
#
#  Working on Opacity Relation #124 out of 161
#
#
#  Working on Opacity Relation #125 out of 161
#
#
#  Working on Opacity Relation #126 out of 161
#
#
#  Working on Opacity Relation #127 out of 161
#
#
#  Working on Opacity Relation #128 out of 161
#
#
#  Working on Opacity Relation #129 out of 161
#
#
#  Working on Opacity Relation #130 out of 161
#
#
#  Working on Opacity Relation #131 out of 161
#
#
#  Working on Opacity Relation #132 out of 161
#
#
#  Working on Opacity Relation #133 out of 161
#
#
#  Working on Opacity Relation #134 out of 161
#
#
#  Working on Opacity Relation #135 out of 161
#
#
#  Working on Opacity Relation #136 out of 161
#
#
#  Working on Opacity Relation #137 out of 161
#
#
#  Working on Opacity Relation #138 out of 161
#
#
#  Working on Opacity Relation #139 out of 161
#
#
#  Working on Opacity Relation #140 out of 161
#
#
#  Working on Opacity Relation #141 out of 161
#
#
#  Working on Opacity Relation #142 out of 161
#
#
#  Working on Opacity Relation #143 out of 161
#
#
#  Working on Opacity Relation #144 out of 161
#
#
#  Working on Opacity Relation #145 out of 161
#
#
#  Working on Opacity Relation #146 out of 161
#
#
#  Working on Opacity Relation #147 out of 161
#
#
#  Working on Opacity Relation #148 out of 161
#
#
#  Working on Opacity Relation #149 out of 161
#
#
#  Working on Opacity Relation #150 out of 161
#
#
#  Working on Opacity Relation #151 out of 161
#
#
#  Working on Opacity Relation #152 out of 161
#
#
#  Working on Opacity Relation #153 out of 161
#
#
#  Working on Opacity Relation #154 out of 161
#
#
#  Working on Opacity Relation #155 out of 161
#
#
#  Working on Opacity Relation #156 out of 161
#
#
#  Working on Opacity Relation #157 out of 161
#
#
#  Working on Opacity Relation #158 out of 161
#
#
#  Working on Opacity Relation #159 out of 161
#
#
#  Working on Opacity Relation #160 out of 161
#
#
#  Working on Opacity Relation #161 out of 161
#
#
#  Working on Opacity Relation #1 out of 1008
#
#
#  Working on Opacity Relation #2 out of 1008
#
#
#  Working on Opacity Relation #3 out of 1008
#
#
#  Working on Opacity Relation #4 out of 1008
#
#
#  Working on Opacity Relation #5 out of 1008
#
#
#  Working on Opacity Relation #6 out of 1008
#
#
#  Working on Opacity Relation #7 out of 1008
#
#
#  Working on Opacity Relation #8 out of 1008
#
#
#  Working on Opacity Relation #9 out of 1008
#
#
#  Working on Opacity Relation #10 out of 1008
#
#
#  Working on Opacity Relation #11 out of 1008
#
#
#  Working on Opacity Relation #12 out of 1008
#
#
#  Working on Opacity Relation #13 out of 1008
#
#
#  Working on Opacity Relation #14 out of 1008
#
#
#  Working on Opacity Relation #15 out of 1008
#
#
#  Working on Opacity Relation #16 out of 1008
#
#
#  Working on Opacity Relation #17 out of 1008
#  Working on Opacity Relation #18 out of 1008
#
#
#  Working on Opacity Relation #19 out of 1008
#
#
#  Working on Opacity Relation #20 out of 1008
#
#
#  Working on Opacity Relation #21 out of 1008
#
#
#  Working on Opacity Relation #22 out of 1008
#
#
#  Working on Opacity Relation #23 out of 1008
#
#
#  Working on Opacity Relation #24 out of 1008
#
#
#  Working on Opacity Relation #25 out of 1008
#
#
#  Working on Opacity Relation #26 out of 1008
#
#
#  Working on Opacity Relation #27 out of 1008
#
#
#  Working on Opacity Relation #28 out of 1008
#
#
#  Working on Opacity Relation #29 out of 1008
#
#
#  Working on Opacity Relation #30 out of 1008
#
#
#  Working on Opacity Relation #31 out of 1008
#
#
#  Working on Opacity Relation #32 out of 1008
#
#
#  Working on Opacity Relation #33 out of 1008
#
#
#  Working on Opacity Relation #34 out of 1008
#
#
#  Working on Opacity Relation #35 out of 1008
#
#
#  Working on Opacity Relation #36 out of 1008
#
#
#  Working on Opacity Relation #37 out of 1008
#
#
#  Working on Opacity Relation #38 out of 1008
#
#
#  Working on Opacity Relation #39 out of 1008
#
#
#  Working on Opacity Relation #40 out of 1008
#
#
#  Working on Opacity Relation #41 out of 1008
#
#
#  Working on Opacity Relation #42 out of 1008
#
#
#  Working on Opacity Relation #43 out of 1008
#
#
#  Working on Opacity Relation #44 out of 1008
#
#
#  Working on Opacity Relation #45 out of 1008
#
#
#  Working on Opacity Relation #46 out of 1008
#
#
#  Working on Opacity Relation #47 out of 1008
#
#
#  Working on Opacity Relation #48 out of 1008
#
#
#  Working on Opacity Relation #49 out of 1008
#
#
#  Working on Opacity Relation #50 out of 1008
#
#
#  Working on Opacity Relation #51 out of 1008
#
#
#  Working on Opacity Relation #52 out of 1008
#
#
#  Working on Opacity Relation #53 out of 1008
#
#
#  Working on Opacity Relation #54 out of 1008
#
#
#  Working on Opacity Relation #55 out of 1008
#
#
#  Working on Opacity Relation #56 out of 1008
#
#
#  Working on Opacity Relation #57 out of 1008
#
#
#  Working on Opacity Relation #58 out of 1008
#
#
#  Working on Opacity Relation #59 out of 1008
#
#
#  Working on Opacity Relation #60 out of 1008
#
#
#  Working on Opacity Relation #61 out of 1008
#
#
#  Working on Opacity Relation #62 out of 1008
#
#
#  Working on Opacity Relation #63 out of 1008
#
#
#  Working on Opacity Relation #64 out of 1008
#
#
#  Working on Opacity Relation #65 out of 1008
#
#
#  Working on Opacity Relation #66 out of 1008
#
#
#  Working on Opacity Relation #67 out of 1008
#
#
#  Working on Opacity Relation #68 out of 1008
#
#
#  Working on Opacity Relation #69 out of 1008
#
#
#  Working on Opacity Relation #70 out of 1008
#
#
#  Working on Opacity Relation #71 out of 1008
#
#
#  Working on Opacity Relation #72 out of 1008
#
#
#  Working on Opacity Relation #73 out of 1008
#
#
#  Working on Opacity Relation #74 out of 1008
#
#
#  Working on Opacity Relation #75 out of 1008
#
#
#  Working on Opacity Relation #76 out of 1008
#
#
#  Working on Opacity Relation #77 out of 1008
#
#
#  Working on Opacity Relation #78 out of 1008
#
#
#  Working on Opacity Relation #79 out of 1008
#
#
#  Working on Opacity Relation #80 out of 1008
#
#
#  Working on Opacity Relation #81 out of 1008
#
#
#  Working on Opacity Relation #82 out of 1008
#
#
#  Working on Opacity Relation #83 out of 1008
#
#
#  Working on Opacity Relation #84 out of 1008
#
#
#  Working on Opacity Relation #85 out of 1008
#
#
#  Working on Opacity Relation #86 out of 1008
#
#
#  Working on Opacity Relation #87 out of 1008
#
#
#  Working on Opacity Relation #88 out of 1008
#
#
#  Working on Opacity Relation #89 out of 1008
#
#
#  Working on Opacity Relation #90 out of 1008
#
#
#  Working on Opacity Relation #91 out of 1008
#
#
#  Working on Opacity Relation #92 out of 1008
#
#
#  Working on Opacity Relation #93 out of 1008
#
#
#  Working on Opacity Relation #94 out of 1008
#
#
#  Working on Opacity Relation #95 out of 1008
#
#
#  Working on Opacity Relation #96 out of 1008
#
#
#  Working on Opacity Relation #97 out of 1008
#
#
#  Working on Opacity Relation #98 out of 1008
#
#
#  Working on Opacity Relation #99 out of 1008
#
#
#  Working on Opacity Relation #100 out of 1008
#
#
#  Working on Opacity Relation #101 out of 1008
#
#
#  Working on Opacity Relation #102 out of 1008
#
#
#  Working on Opacity Relation #103 out of 1008
#
#
#  Working on Opacity Relation #104 out of 1008
#
#
#  Working on Opacity Relation #105 out of 1008
#
#
#  Working on Opacity Relation #106 out of 1008
#
#
#  Working on Opacity Relation #107 out of 1008
#
#
#  Working on Opacity Relation #108 out of 1008
#
#
#  Working on Opacity Relation #109 out of 1008
#
#
#  Working on Opacity Relation #110 out of 1008
#
#
#  Working on Opacity Relation #111 out of 1008
#
#
#  Working on Opacity Relation #112 out of 1008
#
#
#  Working on Opacity Relation #113 out of 1008
#
#
#  Working on Opacity Relation #114 out of 1008
#
#
#  Working on Opacity Relation #115 out of 1008
#
#
#  Working on Opacity Relation #116 out of 1008
#
#
#  Working on Opacity Relation #117 out of 1008
#
#
#  Working on Opacity Relation #118 out of 1008
#
#
#  Working on Opacity Relation #119 out of 1008
#
#
#  Working on Opacity Relation #120 out of 1008
#
#
#  Working on Opacity Relation #121 out of 1008
#
#
#  Working on Opacity Relation #122 out of 1008
#
#
#  Working on Opacity Relation #123 out of 1008
#
#
#  Working on Opacity Relation #124 out of 1008
#
#
#  Working on Opacity Relation #125 out of 1008
#
#
#  Working on Opacity Relation #126 out of 1008
#
#
#  Working on Opacity Relation #127 out of 1008
#
#
#  Working on Opacity Relation #128 out of 1008
#
#
#  Working on Opacity Relation #129 out of 1008
#
#
#  Working on Opacity Relation #130 out of 1008
#
#
#  Working on Opacity Relation #131 out of 1008
#
#
#  Working on Opacity Relation #132 out of 1008
#
#
#  Working on Opacity Relation #133 out of 1008
#
#
#  Working on Opacity Relation #134 out of 1008
#
#
#  Working on Opacity Relation #135 out of 1008
#
#
#  Working on Opacity Relation #136 out of 1008
#
#
#  Working on Opacity Relation #137 out of 1008
#
#
#  Working on Opacity Relation #138 out of 1008
#
#
#  Working on Opacity Relation #139 out of 1008
#
#
#  Working on Opacity Relation #140 out of 1008
#
#
#  Working on Opacity Relation #141 out of 1008
#
#
#  Working on Opacity Relation #142 out of 1008
#
#
#  Working on Opacity Relation #143 out of 1008
#
#
#  Working on Opacity Relation #144 out of 1008
#
#
#  Working on Opacity Relation #145 out of 1008
#
#
#  Working on Opacity Relation #146 out of 1008
#
#
#  Working on Opacity Relation #147 out of 1008
#
#
#  Working on Opacity Relation #148 out of 1008
#
#
#  Working on Opacity Relation #149 out of 1008
#
#
#  Working on Opacity Relation #150 out of 1008
#
#
#  Working on Opacity Relation #151 out of 1008
#
#
#  Working on Opacity Relation #152 out of 1008
#
#
#  Working on Opacity Relation #153 out of 1008
#
#
#  Working on Opacity Relation #154 out of 1008
#
#
#  Working on Opacity Relation #155 out of 1008
#
#
#  Working on Opacity Relation #156 out of 1008
#
#
#  Working on Opacity Relation #157 out of 1008
#
#
#  Working on Opacity Relation #158 out of 1008
#
#
#  Working on Opacity Relation #159 out of 1008
#
#
#  Working on Opacity Relation #160 out of 1008
#
#
#  Working on Opacity Relation #161 out of 1008
#
#
#  Working on Opacity Relation #162 out of 1008
#
#
#  Working on Opacity Relation #163 out of 1008
#
#
#  Working on Opacity Relation #164 out of 1008
#
#
#  Working on Opacity Relation #165 out of 1008
#
#
#  Working on Opacity Relation #166 out of 1008
#
#
#  Working on Opacity Relation #167 out of 1008
#
#
#  Working on Opacity Relation #168 out of 1008
#
#
#  Working on Opacity Relation #169 out of 1008
#
#
#  Working on Opacity Relation #170 out of 1008
#
#
#  Working on Opacity Relation #171 out of 1008
#
#
#  Working on Opacity Relation #172 out of 1008
#
#
#  Working on Opacity Relation #173 out of 1008
#
#
#  Working on Opacity Relation #174 out of 1008
#
#
#  Working on Opacity Relation #175 out of 1008
#
#
#  Working on Opacity Relation #176 out of 1008
#
#
#  Working on Opacity Relation #177 out of 1008
#
#
#  Working on Opacity Relation #178 out of 1008
#
#
#  Working on Opacity Relation #179 out of 1008
#
#
#  Working on Opacity Relation #180 out of 1008
#
#
#  Working on Opacity Relation #181 out of 1008
#
#
#  Working on Opacity Relation #182 out of 1008
#
#
#  Working on Opacity Relation #183 out of 1008
#
#
#  Working on Opacity Relation #184 out of 1008
#
#
#  Working on Opacity Relation #185 out of 1008
#
#
#  Working on Opacity Relation #186 out of 1008
#
#
#  Working on Opacity Relation #187 out of 1008
#
#
#  Working on Opacity Relation #188 out of 1008
#
#
#  Working on Opacity Relation #189 out of 1008
#
#
#  Working on Opacity Relation #190 out of 1008
#  Working on Opacity Relation #191 out of 1008
#
#
#  Working on Opacity Relation #192 out of 1008
#
#
#  Working on Opacity Relation #193 out of 1008
#
#
#  Working on Opacity Relation #194 out of 1008
#
#
#  Working on Opacity Relation #195 out of 1008
#
#
#  Working on Opacity Relation #196 out of 1008
#
#
#  Working on Opacity Relation #197 out of 1008
#
#
#  Working on Opacity Relation #198 out of 1008
#
#
#  Working on Opacity Relation #199 out of 1008
#
#
#  Working on Opacity Relation #200 out of 1008
#
#
#  Working on Opacity Relation #201 out of 1008
#
#
#  Working on Opacity Relation #202 out of 1008
#
#
#  Working on Opacity Relation #203 out of 1008
#
#
#  Working on Opacity Relation #204 out of 1008
#
#
#  Working on Opacity Relation #205 out of 1008
#
#
#  Working on Opacity Relation #206 out of 1008
#
#
#  Working on Opacity Relation #207 out of 1008
#
#
#  Working on Opacity Relation #208 out of 1008
#
#
#  Working on Opacity Relation #209 out of 1008
#
#
#  Working on Opacity Relation #210 out of 1008
#
#
#  Working on Opacity Relation #211 out of 1008
#
#
#  Working on Opacity Relation #212 out of 1008
#
#
#  Working on Opacity Relation #213 out of 1008
#
#
#  Working on Opacity Relation #214 out of 1008
#
#
#  Working on Opacity Relation #215 out of 1008
#
#
#  Working on Opacity Relation #216 out of 1008
#
#
#  Working on Opacity Relation #217 out of 1008
#
#
#  Working on Opacity Relation #218 out of 1008
#
#
#  Working on Opacity Relation #219 out of 1008
#
#
#  Working on Opacity Relation #220 out of 1008
#
#
#  Working on Opacity Relation #221 out of 1008
#
#
#  Working on Opacity Relation #222 out of 1008
#
#
#  Working on Opacity Relation #223 out of 1008
#
#
#  Working on Opacity Relation #224 out of 1008
#
#
#  Working on Opacity Relation #225 out of 1008
#
#
#  Working on Opacity Relation #226 out of 1008
#
#
#  Working on Opacity Relation #227 out of 1008
#
#
#  Working on Opacity Relation #228 out of 1008
#
#
#  Working on Opacity Relation #229 out of 1008
#
#
#  Working on Opacity Relation #230 out of 1008
#
#
#  Working on Opacity Relation #231 out of 1008
#
#
#  Working on Opacity Relation #232 out of 1008
#
#
#  Working on Opacity Relation #233 out of 1008
#
#
#  Working on Opacity Relation #234 out of 1008
#
#
#  Working on Opacity Relation #235 out of 1008
#
#
#  Working on Opacity Relation #236 out of 1008
#
#
#  Working on Opacity Relation #237 out of 1008
#
#
#  Working on Opacity Relation #238 out of 1008
#
#
#  Working on Opacity Relation #239 out of 1008
#
#
#  Working on Opacity Relation #240 out of 1008
#
#
#  Working on Opacity Relation #241 out of 1008
#
#
#  Working on Opacity Relation #242 out of 1008
#
#
#  Working on Opacity Relation #243 out of 1008
#
#
#  Working on Opacity Relation #244 out of 1008
#
#
#  Working on Opacity Relation #245 out of 1008
#
#
#  Working on Opacity Relation #246 out of 1008
#
#
#  Working on Opacity Relation #247 out of 1008
#
#
#  Working on Opacity Relation #248 out of 1008
#
#
#  Working on Opacity Relation #249 out of 1008
#
#
#  Working on Opacity Relation #250 out of 1008
#
#
#  Working on Opacity Relation #251 out of 1008
#
#
#  Working on Opacity Relation #252 out of 1008
#
#
#  Working on Opacity Relation #253 out of 1008
#
#
#  Working on Opacity Relation #254 out of 1008
#
#
#  Working on Opacity Relation #255 out of 1008
#
#
#  Working on Opacity Relation #256 out of 1008
#
#
#  Working on Opacity Relation #257 out of 1008
#
#
#  Working on Opacity Relation #258 out of 1008
#
#
#  Working on Opacity Relation #259 out of 1008
#
#
#  Working on Opacity Relation #260 out of 1008
#
#
#  Working on Opacity Relation #261 out of 1008
#
#
#  Working on Opacity Relation #262 out of 1008
#
#
#  Working on Opacity Relation #263 out of 1008
#
#
#  Working on Opacity Relation #264 out of 1008
#
#
#  Working on Opacity Relation #265 out of 1008
#
#
#  Working on Opacity Relation #266 out of 1008
#
#
#  Working on Opacity Relation #267 out of 1008
#
#
#  Working on Opacity Relation #268 out of 1008
#
#
#  Working on Opacity Relation #269 out of 1008
#
#
#  Working on Opacity Relation #270 out of 1008
#
#
#  Working on Opacity Relation #271 out of 1008
#
#
#  Working on Opacity Relation #272 out of 1008
#
#
#  Working on Opacity Relation #273 out of 1008
#
#
#  Working on Opacity Relation #274 out of 1008
#
#
#  Working on Opacity Relation #275 out of 1008
#
#
#  Working on Opacity Relation #276 out of 1008
#
#
#  Working on Opacity Relation #277 out of 1008
#
#
#  Working on Opacity Relation #278 out of 1008
#
#
#  Working on Opacity Relation #279 out of 1008
#
#
#  Working on Opacity Relation #280 out of 1008
#
#
#  Working on Opacity Relation #281 out of 1008
#
#
#  Working on Opacity Relation #282 out of 1008
#
#
#  Working on Opacity Relation #283 out of 1008
#
#
#  Working on Opacity Relation #284 out of 1008
#
#
#  Working on Opacity Relation #285 out of 1008
#
#
#  Working on Opacity Relation #286 out of 1008
#
#
#  Working on Opacity Relation #287 out of 1008
#
#
#  Working on Opacity Relation #288 out of 1008
#
#
#  Working on Opacity Relation #289 out of 1008
#
#
#  Working on Opacity Relation #290 out of 1008
#
#
#  Working on Opacity Relation #291 out of 1008
#
#
#  Working on Opacity Relation #292 out of 1008
#
#
#  Working on Opacity Relation #293 out of 1008
#
#
#  Working on Opacity Relation #294 out of 1008
#
#
#  Working on Opacity Relation #295 out of 1008
#
#
#  Working on Opacity Relation #296 out of 1008
#
#
#  Working on Opacity Relation #297 out of 1008
#
#
#  Working on Opacity Relation #298 out of 1008
#
#
#  Working on Opacity Relation #299 out of 1008
#
#
#  Working on Opacity Relation #300 out of 1008
#
#
#  Working on Opacity Relation #301 out of 1008
#
#
#  Working on Opacity Relation #302 out of 1008
#
#
#  Working on Opacity Relation #303 out of 1008
#
#
#  Working on Opacity Relation #304 out of 1008
#
#
#  Working on Opacity Relation #305 out of 1008
#
#
#  Working on Opacity Relation #306 out of 1008
#
#
#  Working on Opacity Relation #307 out of 1008
#
#
#  Working on Opacity Relation #308 out of 1008
#
#
#  Working on Opacity Relation #309 out of 1008
#
#
#  Working on Opacity Relation #310 out of 1008
#
#
#  Working on Opacity Relation #311 out of 1008
#
#
#  Working on Opacity Relation #312 out of 1008
#
#
#  Working on Opacity Relation #313 out of 1008
#
#
#  Working on Opacity Relation #314 out of 1008
#
#
#  Working on Opacity Relation #315 out of 1008
#
#
#  Working on Opacity Relation #316 out of 1008
#
#
#  Working on Opacity Relation #317 out of 1008
#
#
#  Working on Opacity Relation #318 out of 1008
#
#
#  Working on Opacity Relation #319 out of 1008
#
#
#  Working on Opacity Relation #320 out of 1008
#
#
#  Working on Opacity Relation #321 out of 1008
#
#
#  Working on Opacity Relation #322 out of 1008
#
#
#  Working on Opacity Relation #323 out of 1008
#
#
#  Working on Opacity Relation #324 out of 1008
#
#
#  Working on Opacity Relation #325 out of 1008
#
#
#  Working on Opacity Relation #326 out of 1008
#
#
#  Working on Opacity Relation #327 out of 1008
#
#
#  Working on Opacity Relation #328 out of 1008
#
#
#  Working on Opacity Relation #329 out of 1008
#
#
#  Working on Opacity Relation #330 out of 1008
#
#
#  Working on Opacity Relation #331 out of 1008
#
#
#  Working on Opacity Relation #332 out of 1008
#
#
#  Working on Opacity Relation #333 out of 1008
#
#
#  Working on Opacity Relation #334 out of 1008
#
#
#  Working on Opacity Relation #335 out of 1008
#
#
#  Working on Opacity Relation #336 out of 1008
#
#
#  Working on Opacity Relation #337 out of 1008
#
#
#  Working on Opacity Relation #338 out of 1008
#
#
#  Working on Opacity Relation #339 out of 1008
#
#
#  Working on Opacity Relation #340 out of 1008
#
#
#  Working on Opacity Relation #341 out of 1008
#
#
#  Working on Opacity Relation #342 out of 1008
#
#
#  Working on Opacity Relation #343 out of 1008
#
#
#  Working on Opacity Relation #344 out of 1008
#
#
#  Working on Opacity Relation #345 out of 1008
#
#
#  Working on Opacity Relation #346 out of 1008
#
#
#  Working on Opacity Relation #347 out of 1008
#
#
#  Working on Opacity Relation #348 out of 1008
#
#
#  Working on Opacity Relation #349 out of 1008
#
#
#  Working on Opacity Relation #350 out of 1008
#
#
#  Working on Opacity Relation #351 out of 1008
#
#
#  Working on Opacity Relation #352 out of 1008
#
#
#  Working on Opacity Relation #353 out of 1008
#
#
#  Working on Opacity Relation #354 out of 1008
#
#
#  Working on Opacity Relation #355 out of 1008
#
#
#  Working on Opacity Relation #356 out of 1008
#
#
#  Working on Opacity Relation #357 out of 1008
#
#
#  Working on Opacity Relation #358 out of 1008
#
#
#  Working on Opacity Relation #359 out of 1008
#
#
#  Working on Opacity Relation #360 out of 1008
#
#
#  Working on Opacity Relation #361 out of 1008
#  Working on Opacity Relation #362 out of 1008
#
#
#  Working on Opacity Relation #363 out of 1008
#
#
#  Working on Opacity Relation #364 out of 1008
#
#
#  Working on Opacity Relation #365 out of 1008
#
#
#  Working on Opacity Relation #366 out of 1008
#
#
#  Working on Opacity Relation #367 out of 1008
#
#
#  Working on Opacity Relation #368 out of 1008
#
#
#  Working on Opacity Relation #369 out of 1008
#
#
#  Working on Opacity Relation #370 out of 1008
#
#
#  Working on Opacity Relation #371 out of 1008
#
#
#  Working on Opacity Relation #372 out of 1008
#
#
#  Working on Opacity Relation #373 out of 1008
#
#
#  Working on Opacity Relation #374 out of 1008
#
#
#  Working on Opacity Relation #375 out of 1008
#
#
#  Working on Opacity Relation #376 out of 1008
#
#
#  Working on Opacity Relation #377 out of 1008
#
#
#  Working on Opacity Relation #378 out of 1008
#
#
#  Working on Opacity Relation #379 out of 1008
#
#
#  Working on Opacity Relation #380 out of 1008
#
#
#  Working on Opacity Relation #381 out of 1008
#
#
#  Working on Opacity Relation #382 out of 1008
#
#
#  Working on Opacity Relation #383 out of 1008
#
#
#  Working on Opacity Relation #384 out of 1008
#
#
#  Working on Opacity Relation #385 out of 1008
#
#
#  Working on Opacity Relation #386 out of 1008
#
#
#  Working on Opacity Relation #387 out of 1008
#
#
#  Working on Opacity Relation #388 out of 1008
#
#
#  Working on Opacity Relation #389 out of 1008
#
#
#  Working on Opacity Relation #390 out of 1008
#
#
#  Working on Opacity Relation #391 out of 1008
#
#
#  Working on Opacity Relation #392 out of 1008
#
#
#  Working on Opacity Relation #393 out of 1008
#
#
#  Working on Opacity Relation #394 out of 1008
#
#
#  Working on Opacity Relation #395 out of 1008
#
#
#  Working on Opacity Relation #396 out of 1008
#
#
#  Working on Opacity Relation #397 out of 1008
#
#
#  Working on Opacity Relation #398 out of 1008
#
#
#  Working on Opacity Relation #399 out of 1008
#
#
#  Working on Opacity Relation #400 out of 1008
#
#
#  Working on Opacity Relation #401 out of 1008
#
#
#  Working on Opacity Relation #402 out of 1008
#
#
#  Working on Opacity Relation #403 out of 1008
#
#
#  Working on Opacity Relation #404 out of 1008
#
#
#  Working on Opacity Relation #405 out of 1008
#
#
#  Working on Opacity Relation #406 out of 1008
#
#
#  Working on Opacity Relation #407 out of 1008
#
#
#  Working on Opacity Relation #408 out of 1008
#
#
#  Working on Opacity Relation #409 out of 1008
#
#
#  Working on Opacity Relation #410 out of 1008
#
#
#  Working on Opacity Relation #411 out of 1008
#
#
#  Working on Opacity Relation #412 out of 1008
#
#
#  Working on Opacity Relation #413 out of 1008
#
#
#  Working on Opacity Relation #414 out of 1008
#
#
#  Working on Opacity Relation #415 out of 1008
#
#
#  Working on Opacity Relation #416 out of 1008
#
#
#  Working on Opacity Relation #417 out of 1008
#
#
#  Working on Opacity Relation #418 out of 1008
#
#
#  Working on Opacity Relation #419 out of 1008
#
#
#  Working on Opacity Relation #420 out of 1008
#
#
#  Working on Opacity Relation #421 out of 1008
#
#
#  Working on Opacity Relation #422 out of 1008
#
#
#  Working on Opacity Relation #423 out of 1008
#
#
#  Working on Opacity Relation #424 out of 1008
#
#
#  Working on Opacity Relation #425 out of 1008
#
#
#  Working on Opacity Relation #426 out of 1008
#
#
#  Working on Opacity Relation #427 out of 1008
#
#
#  Working on Opacity Relation #428 out of 1008
#
#
#  Working on Opacity Relation #429 out of 1008
#
#
#  Working on Opacity Relation #430 out of 1008
#
#
#  Working on Opacity Relation #431 out of 1008
#
#
#  Working on Opacity Relation #432 out of 1008
#
#
#  Working on Opacity Relation #433 out of 1008
#
#
#  Working on Opacity Relation #434 out of 1008
#
#
#  Working on Opacity Relation #435 out of 1008
#
#
#  Working on Opacity Relation #436 out of 1008
#
#
#  Working on Opacity Relation #437 out of 1008
#
#
#  Working on Opacity Relation #438 out of 1008
#
#
#  Working on Opacity Relation #439 out of 1008
#
#
#  Working on Opacity Relation #440 out of 1008
#
#
#  Working on Opacity Relation #441 out of 1008
#
#
#  Working on Opacity Relation #442 out of 1008
#
#
#  Working on Opacity Relation #443 out of 1008
#
#
#  Working on Opacity Relation #444 out of 1008
#
#
#  Working on Opacity Relation #445 out of 1008
#
#
#  Working on Opacity Relation #446 out of 1008
#
#
#  Working on Opacity Relation #447 out of 1008
#
#
#  Working on Opacity Relation #448 out of 1008
#
#
#  Working on Opacity Relation #449 out of 1008
#
#
#  Working on Opacity Relation #450 out of 1008
#
#
#  Working on Opacity Relation #451 out of 1008
#
#
#  Working on Opacity Relation #452 out of 1008
#
#
#  Working on Opacity Relation #453 out of 1008
#
#
#  Working on Opacity Relation #454 out of 1008
#
#
#  Working on Opacity Relation #455 out of 1008
#
#
#  Working on Opacity Relation #456 out of 1008
#
#
#  Working on Opacity Relation #457 out of 1008
#
#
#  Working on Opacity Relation #458 out of 1008
#
#
#  Working on Opacity Relation #459 out of 1008
#
#
#  Working on Opacity Relation #460 out of 1008
#
#
#  Working on Opacity Relation #461 out of 1008
#
#
#  Working on Opacity Relation #462 out of 1008
#
#
#  Working on Opacity Relation #463 out of 1008
#
#
#  Working on Opacity Relation #464 out of 1008
#
#
#  Working on Opacity Relation #465 out of 1008
#
#
#  Working on Opacity Relation #466 out of 1008
#
#
#  Working on Opacity Relation #467 out of 1008
#
#
#  Working on Opacity Relation #468 out of 1008
#
#
#  Working on Opacity Relation #469 out of 1008
#
#
#  Working on Opacity Relation #470 out of 1008
#
#
#  Working on Opacity Relation #471 out of 1008
#
#
#  Working on Opacity Relation #472 out of 1008
#
#
#  Working on Opacity Relation #473 out of 1008
#
#
#  Working on Opacity Relation #474 out of 1008
#
#
#  Working on Opacity Relation #475 out of 1008
#
#
#  Working on Opacity Relation #476 out of 1008
#
#
#  Working on Opacity Relation #477 out of 1008
#
#
#  Working on Opacity Relation #478 out of 1008
#
#
#  Working on Opacity Relation #479 out of 1008
#
#
#  Working on Opacity Relation #480 out of 1008
#
#
#  Working on Opacity Relation #481 out of 1008
#
#
#  Working on Opacity Relation #482 out of 1008
#
#
#  Working on Opacity Relation #483 out of 1008
#
#
#  Working on Opacity Relation #484 out of 1008
#
#
#  Working on Opacity Relation #485 out of 1008
#
#
#  Working on Opacity Relation #486 out of 1008
#
#
#  Working on Opacity Relation #487 out of 1008
#
#
#  Working on Opacity Relation #488 out of 1008
#
#
#  Working on Opacity Relation #489 out of 1008
#
#
#  Working on Opacity Relation #490 out of 1008
#
#
#  Working on Opacity Relation #491 out of 1008
#
#
#  Working on Opacity Relation #492 out of 1008
#
#
#  Working on Opacity Relation #493 out of 1008
#
#
#  Working on Opacity Relation #494 out of 1008
#
#
#  Working on Opacity Relation #495 out of 1008
#
#
#  Working on Opacity Relation #496 out of 1008
#
#
#  Working on Opacity Relation #497 out of 1008
#
#
#  Working on Opacity Relation #498 out of 1008
#
#
#  Working on Opacity Relation #499 out of 1008
#
#
#  Working on Opacity Relation #500 out of 1008
#
#
#  Working on Opacity Relation #501 out of 1008
#
#
#  Working on Opacity Relation #502 out of 1008
#
#
#  Working on Opacity Relation #503 out of 1008
#
#
#  Working on Opacity Relation #504 out of 1008
#
#
#  Working on Opacity Relation #505 out of 1008
#
#
#  Working on Opacity Relation #506 out of 1008
#
#
#  Working on Opacity Relation #507 out of 1008
#
#
#  Working on Opacity Relation #508 out of 1008
#
#
#  Working on Opacity Relation #509 out of 1008
#
#
#  Working on Opacity Relation #510 out of 1008
#
#
#  Working on Opacity Relation #511 out of 1008
#
#
#  Working on Opacity Relation #512 out of 1008
#
#
#  Working on Opacity Relation #513 out of 1008
#
#
#  Working on Opacity Relation #514 out of 1008
#
#
#  Working on Opacity Relation #515 out of 1008
#
#
#  Working on Opacity Relation #516 out of 1008
#
#
#  Working on Opacity Relation #517 out of 1008
#
#
#  Working on Opacity Relation #518 out of 1008
#
#
#  Working on Opacity Relation #519 out of 1008
#
#
#  Working on Opacity Relation #520 out of 1008
#
#
#  Working on Opacity Relation #521 out of 1008
#
#
#  Working on Opacity Relation #522 out of 1008
#
#
#  Working on Opacity Relation #523 out of 1008
#
#
#  Working on Opacity Relation #524 out of 1008
#
#
#  Working on Opacity Relation #525 out of 1008
#
#
#  Working on Opacity Relation #526 out of 1008
#
#
#  Working on Opacity Relation #527 out of 1008
#
#
#  Working on Opacity Relation #528 out of 1008
#
#
#  Working on Opacity Relation #529 out of 1008
#
#
#  Working on Opacity Relation #530 out of 1008
#
#
#  Working on Opacity Relation #531 out of 1008
#
#
#  Working on Opacity Relation #532 out of 1008
#  Working on Opacity Relation #533 out of 1008
#
#
#  Working on Opacity Relation #534 out of 1008
#
#
#  Working on Opacity Relation #535 out of 1008
#
#
#  Working on Opacity Relation #536 out of 1008
#
#
#  Working on Opacity Relation #537 out of 1008
#
#
#  Working on Opacity Relation #538 out of 1008
#
#
#  Working on Opacity Relation #539 out of 1008
#
#
#  Working on Opacity Relation #540 out of 1008
#
#
#  Working on Opacity Relation #541 out of 1008
#
#
#  Working on Opacity Relation #542 out of 1008
#
#
#  Working on Opacity Relation #543 out of 1008
#
#
#  Working on Opacity Relation #544 out of 1008
#
#
#  Working on Opacity Relation #545 out of 1008
#
#
#  Working on Opacity Relation #546 out of 1008
#
#
#  Working on Opacity Relation #547 out of 1008
#
#
#  Working on Opacity Relation #548 out of 1008
#
#
#  Working on Opacity Relation #549 out of 1008
#
#
#  Working on Opacity Relation #550 out of 1008
#
#
#  Working on Opacity Relation #551 out of 1008
#
#
#  Working on Opacity Relation #552 out of 1008
#
#
#  Working on Opacity Relation #553 out of 1008
#
#
#  Working on Opacity Relation #554 out of 1008
#
#
#  Working on Opacity Relation #555 out of 1008
#
#
#  Working on Opacity Relation #556 out of 1008
#
#
#  Working on Opacity Relation #557 out of 1008
#
#
#  Working on Opacity Relation #558 out of 1008
#
#
#  Working on Opacity Relation #559 out of 1008
#
#
#  Working on Opacity Relation #560 out of 1008
#
#
#  Working on Opacity Relation #561 out of 1008
#
#
#  Working on Opacity Relation #562 out of 1008
#
#
#  Working on Opacity Relation #563 out of 1008
#
#
#  Working on Opacity Relation #564 out of 1008
#
#
#  Working on Opacity Relation #565 out of 1008
#
#
#  Working on Opacity Relation #566 out of 1008
#
#
#  Working on Opacity Relation #567 out of 1008
#
#
#  Working on Opacity Relation #568 out of 1008
#
#
#  Working on Opacity Relation #569 out of 1008
#
#
#  Working on Opacity Relation #570 out of 1008
#
#
#  Working on Opacity Relation #571 out of 1008
#
#
#  Working on Opacity Relation #572 out of 1008
#
#
#  Working on Opacity Relation #573 out of 1008
#
#
#  Working on Opacity Relation #574 out of 1008
#
#
#  Working on Opacity Relation #575 out of 1008
#
#
#  Working on Opacity Relation #576 out of 1008
#
#
#  Working on Opacity Relation #577 out of 1008
#
#
#  Working on Opacity Relation #578 out of 1008
#
#
#  Working on Opacity Relation #579 out of 1008
#
#
#  Working on Opacity Relation #580 out of 1008
#
#
#  Working on Opacity Relation #581 out of 1008
#
#
#  Working on Opacity Relation #582 out of 1008
#
#
#  Working on Opacity Relation #583 out of 1008
#
#
#  Working on Opacity Relation #584 out of 1008
#
#
#  Working on Opacity Relation #585 out of 1008
#
#
#  Working on Opacity Relation #586 out of 1008
#
#
#  Working on Opacity Relation #587 out of 1008
#
#
#  Working on Opacity Relation #588 out of 1008
#
#
#  Working on Opacity Relation #589 out of 1008
#
#
#  Working on Opacity Relation #590 out of 1008
#
#
#  Working on Opacity Relation #591 out of 1008
#
#
#  Working on Opacity Relation #592 out of 1008
#
#
#  Working on Opacity Relation #593 out of 1008
#
#
#  Working on Opacity Relation #594 out of 1008
#
#
#  Working on Opacity Relation #595 out of 1008
#
#
#  Working on Opacity Relation #596 out of 1008
#
#
#  Working on Opacity Relation #597 out of 1008
#
#
#  Working on Opacity Relation #598 out of 1008
#
#
#  Working on Opacity Relation #599 out of 1008
#
#
#  Working on Opacity Relation #600 out of 1008
#
#
#  Working on Opacity Relation #601 out of 1008
#
#
#  Working on Opacity Relation #602 out of 1008
#
#
#  Working on Opacity Relation #603 out of 1008
#
#
#  Working on Opacity Relation #604 out of 1008
#
#
#  Working on Opacity Relation #605 out of 1008
#
#
#  Working on Opacity Relation #606 out of 1008
#
#
#  Working on Opacity Relation #607 out of 1008
#
#
#  Working on Opacity Relation #608 out of 1008
#
#
#  Working on Opacity Relation #609 out of 1008
#
#
#  Working on Opacity Relation #610 out of 1008
#
#
#  Working on Opacity Relation #611 out of 1008
#
#
#  Working on Opacity Relation #612 out of 1008
#
#
#  Working on Opacity Relation #613 out of 1008
#
#
#  Working on Opacity Relation #614 out of 1008
#
#
#  Working on Opacity Relation #615 out of 1008
#
#
#  Working on Opacity Relation #616 out of 1008
#
#
#  Working on Opacity Relation #617 out of 1008
#
#
#  Working on Opacity Relation #618 out of 1008
#
#
#  Working on Opacity Relation #619 out of 1008
#
#
#  Working on Opacity Relation #620 out of 1008
#
#
#  Working on Opacity Relation #621 out of 1008
#
#
#  Working on Opacity Relation #622 out of 1008
#
#
#  Working on Opacity Relation #623 out of 1008
#
#
#  Working on Opacity Relation #624 out of 1008
#
#
#  Working on Opacity Relation #625 out of 1008
#
#
#  Working on Opacity Relation #626 out of 1008
#
#
#  Working on Opacity Relation #627 out of 1008
#
#
#  Working on Opacity Relation #628 out of 1008
#
#
#  Working on Opacity Relation #629 out of 1008
#
#
#  Working on Opacity Relation #630 out of 1008
#
#
#  Working on Opacity Relation #631 out of 1008
#
#
#  Working on Opacity Relation #632 out of 1008
#
#
#  Working on Opacity Relation #633 out of 1008
#
#
#  Working on Opacity Relation #634 out of 1008
#
#
#  Working on Opacity Relation #635 out of 1008
#
#
#  Working on Opacity Relation #636 out of 1008
#
#
#  Working on Opacity Relation #637 out of 1008
#
#
#  Working on Opacity Relation #638 out of 1008
#
#
#  Working on Opacity Relation #639 out of 1008
#
#
#  Working on Opacity Relation #640 out of 1008
#
#
#  Working on Opacity Relation #641 out of 1008
#
#
#  Working on Opacity Relation #642 out of 1008
#
#
#  Working on Opacity Relation #643 out of 1008
#
#
#  Working on Opacity Relation #644 out of 1008
#
#
#  Working on Opacity Relation #645 out of 1008
#
#
#  Working on Opacity Relation #646 out of 1008
#
#
#  Working on Opacity Relation #647 out of 1008
#
#
#  Working on Opacity Relation #648 out of 1008
#
#
#  Working on Opacity Relation #649 out of 1008
#
#
#  Working on Opacity Relation #650 out of 1008
#
#
#  Working on Opacity Relation #651 out of 1008
#
#
#  Working on Opacity Relation #652 out of 1008
#
#
#  Working on Opacity Relation #653 out of 1008
#
#
#  Working on Opacity Relation #654 out of 1008
#
#
#  Working on Opacity Relation #655 out of 1008
#
#
#  Working on Opacity Relation #656 out of 1008
#
#
#  Working on Opacity Relation #657 out of 1008
#
#
#  Working on Opacity Relation #658 out of 1008
#
#
#  Working on Opacity Relation #659 out of 1008
#
#
#  Working on Opacity Relation #660 out of 1008
#
#
#  Working on Opacity Relation #661 out of 1008
#
#
#  Working on Opacity Relation #662 out of 1008
#
#
#  Working on Opacity Relation #663 out of 1008
#
#
#  Working on Opacity Relation #664 out of 1008
#
#
#  Working on Opacity Relation #665 out of 1008
#
#
#  Working on Opacity Relation #666 out of 1008
#
#
#  Working on Opacity Relation #667 out of 1008
#
#
#  Working on Opacity Relation #668 out of 1008
#
#
#  Working on Opacity Relation #669 out of 1008
#
#
#  Working on Opacity Relation #670 out of 1008
#
#
#  Working on Opacity Relation #671 out of 1008
#
#
#  Working on Opacity Relation #672 out of 1008
#
#
#  Working on Opacity Relation #673 out of 1008
#
#
#  Working on Opacity Relation #674 out of 1008
#
#
#  Working on Opacity Relation #675 out of 1008
#
#
#  Working on Opacity Relation #676 out of 1008
#
#
#  Working on Opacity Relation #677 out of 1008
#
#
#  Working on Opacity Relation #678 out of 1008
#
#
#  Working on Opacity Relation #679 out of 1008
#
#
#  Working on Opacity Relation #680 out of 1008
#
#
#  Working on Opacity Relation #681 out of 1008
#
#
#  Working on Opacity Relation #682 out of 1008
#
#
#  Working on Opacity Relation #683 out of 1008
#
#
#  Working on Opacity Relation #684 out of 1008
#
#
#  Working on Opacity Relation #685 out of 1008
#
#
#  Working on Opacity Relation #686 out of 1008
#
#
#  Working on Opacity Relation #687 out of 1008
#
#
#  Working on Opacity Relation #688 out of 1008
#
#
#  Working on Opacity Relation #689 out of 1008
#
#
#  Working on Opacity Relation #690 out of 1008
#
#
#  Working on Opacity Relation #691 out of 1008
#
#
#  Working on Opacity Relation #692 out of 1008
#
#
#  Working on Opacity Relation #693 out of 1008
#
#
#  Working on Opacity Relation #694 out of 1008
#
#
#  Working on Opacity Relation #695 out of 1008
#
#
#  Working on Opacity Relation #696 out of 1008
#
#
#  Working on Opacity Relation #697 out of 1008
#
#
#  Working on Opacity Relation #698 out of 1008
#
#
#  Working on Opacity Relation #699 out of 1008
#
#
#  Working on Opacity Relation #700 out of 1008
#
#
#  Working on Opacity Relation #701 out of 1008
#
#
#  Working on Opacity Relation #702 out of 1008
#
#
#  Working on Opacity Relation #703 out of 1008
#  Working on Opacity Relation #704 out of 1008
#
#
#  Working on Opacity Relation #705 out of 1008
#
#
#  Working on Opacity Relation #706 out of 1008
#
#
#  Working on Opacity Relation #707 out of 1008
#
#
#  Working on Opacity Relation #708 out of 1008
#
#
#  Working on Opacity Relation #709 out of 1008
#
#
#  Working on Opacity Relation #710 out of 1008
#
#
#  Working on Opacity Relation #711 out of 1008
#
#
#  Working on Opacity Relation #712 out of 1008
#
#
#  Working on Opacity Relation #713 out of 1008
#
#
#  Working on Opacity Relation #714 out of 1008
#
#
#  Working on Opacity Relation #715 out of 1008
#
#
#  Working on Opacity Relation #716 out of 1008
#
#
#  Working on Opacity Relation #717 out of 1008
#
#
#  Working on Opacity Relation #718 out of 1008
#
#
#  Working on Opacity Relation #719 out of 1008
#
#
#  Working on Opacity Relation #720 out of 1008
#
#
#  Working on Opacity Relation #721 out of 1008
#
#
#  Working on Opacity Relation #722 out of 1008
#
#
#  Working on Opacity Relation #723 out of 1008
#
#
#  Working on Opacity Relation #724 out of 1008
#
#
#  Working on Opacity Relation #725 out of 1008
#
#
#  Working on Opacity Relation #726 out of 1008
#
#
#  Working on Opacity Relation #727 out of 1008
#
#
#  Working on Opacity Relation #728 out of 1008
#
#
#  Working on Opacity Relation #729 out of 1008
#
#
#  Working on Opacity Relation #730 out of 1008
#
#
#  Working on Opacity Relation #731 out of 1008
#
#
#  Working on Opacity Relation #732 out of 1008
#
#
#  Working on Opacity Relation #733 out of 1008
#
#
#  Working on Opacity Relation #734 out of 1008
#
#
#  Working on Opacity Relation #735 out of 1008
#
#
#  Working on Opacity Relation #736 out of 1008
#
#
#  Working on Opacity Relation #737 out of 1008
#
#
#  Working on Opacity Relation #738 out of 1008
#
#
#  Working on Opacity Relation #739 out of 1008
#
#
#  Working on Opacity Relation #740 out of 1008
#
#
#  Working on Opacity Relation #741 out of 1008
#
#
#  Working on Opacity Relation #742 out of 1008
#
#
#  Working on Opacity Relation #743 out of 1008
#
#
#  Working on Opacity Relation #744 out of 1008
#
#
#  Working on Opacity Relation #745 out of 1008
#
#
#  Working on Opacity Relation #746 out of 1008
#
#
#  Working on Opacity Relation #747 out of 1008
#
#
#  Working on Opacity Relation #748 out of 1008
#
#
#  Working on Opacity Relation #749 out of 1008
#
#
#  Working on Opacity Relation #750 out of 1008
#
#
#  Working on Opacity Relation #751 out of 1008
#
#
#  Working on Opacity Relation #752 out of 1008
#
#
#  Working on Opacity Relation #753 out of 1008
#
#
#  Working on Opacity Relation #754 out of 1008
#
#
#  Working on Opacity Relation #755 out of 1008
#
#
#  Working on Opacity Relation #756 out of 1008
#
#
#  Working on Opacity Relation #757 out of 1008
#
#
#  Working on Opacity Relation #758 out of 1008
#
#
#  Working on Opacity Relation #759 out of 1008
#
#
#  Working on Opacity Relation #760 out of 1008
#
#
#  Working on Opacity Relation #761 out of 1008
#
#
#  Working on Opacity Relation #762 out of 1008
#
#
#  Working on Opacity Relation #763 out of 1008
#
#
#  Working on Opacity Relation #764 out of 1008
#
#
#  Working on Opacity Relation #765 out of 1008
#
#
#  Working on Opacity Relation #766 out of 1008
#
#
#  Working on Opacity Relation #767 out of 1008
#
#
#  Working on Opacity Relation #768 out of 1008
#
#
#  Working on Opacity Relation #769 out of 1008
#
#
#  Working on Opacity Relation #770 out of 1008
#
#
#  Working on Opacity Relation #771 out of 1008
#
#
#  Working on Opacity Relation #772 out of 1008
#
#
#  Working on Opacity Relation #773 out of 1008
#
#
#  Working on Opacity Relation #774 out of 1008
#
#
#  Working on Opacity Relation #775 out of 1008
#
#
#  Working on Opacity Relation #776 out of 1008
#
#
#  Working on Opacity Relation #777 out of 1008
#
#
#  Working on Opacity Relation #778 out of 1008
#
#
#  Working on Opacity Relation #779 out of 1008
#
#
#  Working on Opacity Relation #780 out of 1008
#
#
#  Working on Opacity Relation #781 out of 1008
#
#
#  Working on Opacity Relation #782 out of 1008
#
#
#  Working on Opacity Relation #783 out of 1008
#
#
#  Working on Opacity Relation #784 out of 1008
#
#
#  Working on Opacity Relation #785 out of 1008
#
#
#  Working on Opacity Relation #786 out of 1008
#
#
#  Working on Opacity Relation #787 out of 1008
#
#
#  Working on Opacity Relation #788 out of 1008
#
#
#  Working on Opacity Relation #789 out of 1008
#
#
#  Working on Opacity Relation #790 out of 1008
#
#
#  Working on Opacity Relation #791 out of 1008
#
#
#  Working on Opacity Relation #792 out of 1008
#
#
#  Working on Opacity Relation #793 out of 1008
#
#
#  Working on Opacity Relation #794 out of 1008
#
#
#  Working on Opacity Relation #795 out of 1008
#
#
#  Working on Opacity Relation #796 out of 1008
#
#
#  Working on Opacity Relation #797 out of 1008
#
#
#  Working on Opacity Relation #798 out of 1008
#
#
#  Working on Opacity Relation #799 out of 1008
#
#
#  Working on Opacity Relation #800 out of 1008
#
#
#  Working on Opacity Relation #801 out of 1008
#
#
#  Working on Opacity Relation #802 out of 1008
#
#
#  Working on Opacity Relation #803 out of 1008
#
#
#  Working on Opacity Relation #804 out of 1008
#
#
#  Working on Opacity Relation #805 out of 1008
#
#
#  Working on Opacity Relation #806 out of 1008
#
#
#  Working on Opacity Relation #807 out of 1008
#
#
#  Working on Opacity Relation #808 out of 1008
#
#
#  Working on Opacity Relation #809 out of 1008
#
#
#  Working on Opacity Relation #810 out of 1008
#
#
#  Working on Opacity Relation #811 out of 1008
#
#
#  Working on Opacity Relation #812 out of 1008
#
#
#  Working on Opacity Relation #813 out of 1008
#
#
#  Working on Opacity Relation #814 out of 1008
#
#
#  Working on Opacity Relation #815 out of 1008
#
#
#  Working on Opacity Relation #816 out of 1008
#
#
#  Working on Opacity Relation #817 out of 1008
#
#
#  Working on Opacity Relation #818 out of 1008
#
#
#  Working on Opacity Relation #819 out of 1008
#
#
#  Working on Opacity Relation #820 out of 1008
#
#
#  Working on Opacity Relation #821 out of 1008
#
#
#  Working on Opacity Relation #822 out of 1008
#
#
#  Working on Opacity Relation #823 out of 1008
#
#
#  Working on Opacity Relation #824 out of 1008
#
#
#  Working on Opacity Relation #825 out of 1008
#
#
#  Working on Opacity Relation #826 out of 1008
#
#
#  Working on Opacity Relation #827 out of 1008
#
#
#  Working on Opacity Relation #828 out of 1008
#
#
#  Working on Opacity Relation #829 out of 1008
#
#
#  Working on Opacity Relation #830 out of 1008
#
#
#  Working on Opacity Relation #831 out of 1008
#
#
#  Working on Opacity Relation #832 out of 1008
#
#
#  Working on Opacity Relation #833 out of 1008
#
#
#  Working on Opacity Relation #834 out of 1008
#
#
#  Working on Opacity Relation #835 out of 1008
#
#
#  Working on Opacity Relation #836 out of 1008
#
#
#  Working on Opacity Relation #837 out of 1008
#
#
#  Working on Opacity Relation #838 out of 1008
#
#
#  Working on Opacity Relation #839 out of 1008
#
#
#  Working on Opacity Relation #840 out of 1008
#
#
#  Working on Opacity Relation #841 out of 1008
#
#
#  Working on Opacity Relation #842 out of 1008
#
#
#  Working on Opacity Relation #843 out of 1008
#
#
#  Working on Opacity Relation #844 out of 1008
#
#
#  Working on Opacity Relation #845 out of 1008
#
#
#  Working on Opacity Relation #846 out of 1008
#
#
#  Working on Opacity Relation #847 out of 1008
#
#
# ...
#  (4.9999999999999964, 0.009399999999999992),
#  (4.9999999999999964, 0.00959999999999999),
#  (4.9999999999999964, 0.00979999999999999),
#  (4.9999999999999964, 0.00999999999999999),
#  (4.9999999999999964, 0.01019999999999999),
#  (4.9999999999999964, 0.010399999999999989),
#  (4.9999999999999964, 0.010599999999999988),
#  (4.9999999999999964, 0.010799999999999988),
#  (4.9999999999999964, 0.010999999999999989),
#  (4.9999999999999964, 0.011199999999999988),
#  (4.9999999999999964, 0.011399999999999987),
#  (4.9999999999999964, 0.011599999999999987),
#  (4.9999999999999964, 0.011799999999999988),
#  (4.9999999999999964, 0.011999999999999986),
#  (4.9999999999999964, 0.012199999999999985),
#  (4.9999999999999964, 0.012399999999999986),
#  (4.9999999999999964, 0.012599999999999986),
#  (4.9999999999999964, 0.012799999999999985),
#  (4.9999999999999964, 0.012999999999999984),
#  (4.9999999999999964, 0.013199999999999984),
#  (4.9999999999999964, 0.013399999999999985),
#  (4.9999999999999964, 0.013599999999999984),
#  (5.099999999999996, 0.004),
#  (5.099999999999996, 0.0042),
#  (5.099999999999996, 0.004399999999999999),
#  (5.099999999999996, 0.004599999999999999),
#  (5.099999999999996, 0.004799999999999999),
#  (5.099999999999996, 0.004999999999999998),
#  (5.099999999999996, 0.005199999999999998),
#  (5.099999999999996, 0.005399999999999998),
#  (5.099999999999996, 0.005599999999999997),
#  (5.099999999999996, 0.005799999999999997),
#  (5.099999999999996, 0.005999999999999997),
#  (5.099999999999996, 0.006199999999999996),
#  (5.099999999999996, 0.006399999999999996),
#  (5.099999999999996, 0.006599999999999996),
#  (5.099999999999996, 0.006799999999999995),
#  (5.099999999999996, 0.006999999999999995),
#  (5.099999999999996, 0.007199999999999995),
#  (5.099999999999996, 0.007399999999999994),
#  (5.099999999999996, 0.007599999999999994),
#  (5.099999999999996, 0.007799999999999994),
#  (5.099999999999996, 0.007999999999999993),
#  (5.099999999999996, 0.008199999999999992),
#  (5.099999999999996, 0.008399999999999993),
#  (5.099999999999996, 0.008599999999999993),
#  (5.099999999999996, 0.008799999999999992),
#  (5.099999999999996, 0.00899999999999999),
#  (5.099999999999996, 0.009199999999999991),
#  (5.099999999999996, 0.009399999999999992),
#  (5.099999999999996, 0.00959999999999999),
#  (5.099999999999996, 0.00979999999999999),
#  (5.099999999999996, 0.00999999999999999),
#  (5.099999999999996, 0.01019999999999999),
#  (5.099999999999996, 0.010399999999999989),
#  (5.099999999999996, 0.010599999999999988),
#  (5.099999999999996, 0.010799999999999988),
#  (5.099999999999996, 0.010999999999999989),
#  (5.099999999999996, 0.011199999999999988),
#  (5.099999999999996, 0.011399999999999987),
#  (5.099999999999996, 0.011599999999999987),
#  (5.099999999999996, 0.011799999999999988),
#  (5.099999999999996, 0.011999999999999986),
#  (5.099999999999996, 0.012199999999999985),
#  (5.099999999999996, 0.012399999999999986),
#  (5.099999999999996, 0.012599999999999986),
#  (5.099999999999996, 0.012799999999999985),
#  (5.099999999999996, 0.012999999999999984),
#  (5.099999999999996, 0.013199999999999984),
#  (5.099999999999996, 0.013399999999999985),
#  (5.099999999999996, 0.013599999999999984),
#  (5.099999999999996, 0.013799999999999982),
#  (5.099999999999996, 0.013999999999999983),
#  (5.199999999999996, 0.004),
#  (5.199999999999996, 0.0042),
#  (5.199999999999996, 0.004399999999999999),
#  (5.199999999999996, 0.004599999999999999),
#  (5.199999999999996, 0.004799999999999999),
#  (5.199999999999996, 0.004999999999999998),
#  (5.199999999999996, 0.005199999999999998),
#  (5.199999999999996, 0.005399999999999998),
#  (5.199999999999996, 0.005599999999999997),
#  (5.199999999999996, 0.005799999999999997),
#  (5.199999999999996, 0.005999999999999997),
#  (5.199999999999996, 0.006199999999999996),
#  (5.199999999999996, 0.006399999999999996),
#  (5.199999999999996, 0.006599999999999996),
#  (5.199999999999996, 0.006799999999999995),
#  (5.199999999999996, 0.006999999999999995),
#  (5.199999999999996, 0.007199999999999995),
#  (5.199999999999996, 0.007399999999999994),
#  (5.199999999999996, 0.007599999999999994),
#  (5.199999999999996, 0.007799999999999994),
#  (5.199999999999996, 0.007999999999999993),
#  (5.199999999999996, 0.008199999999999992),
#  (5.199999999999996, 0.008399999999999993),
#  (5.199999999999996, 0.008599999999999993),
#  (5.199999999999996, 0.008799999999999992),
#  (5.199999999999996, 0.00899999999999999),
#  (5.199999999999996, 0.009199999999999991),
#  (5.199999999999996, 0.009399999999999992),
#  (5.199999999999996, 0.00959999999999999),
#  (5.199999999999996, 0.00979999999999999),
#  (5.199999999999996, 0.00999999999999999),
#  (5.199999999999996, 0.01019999999999999),
#  (5.199999999999996, 0.010399999999999989),
#  (5.199999999999996, 0.010599999999999988),
#  (5.199999999999996, 0.010799999999999988),
#  (5.199999999999996, 0.010999999999999989),
#  (5.199999999999996, 0.011199999999999988),
#  (5.199999999999996, 0.011399999999999987),
#  (5.199999999999996, 0.011599999999999987),
#  (5.199999999999996, 0.011799999999999988),
#  (5.199999999999996, 0.011999999999999986),
#  (5.199999999999996, 0.012199999999999985),
#  (5.199999999999996, 0.012399999999999986),
#  (5.199999999999996, 0.012599999999999986),
#  (5.199999999999996, 0.012799999999999985),
#  (5.199999999999996, 0.012999999999999984),
#  (5.199999999999996, 0.013199999999999984),
#  (5.199999999999996, 0.013399999999999985),
#  (5.199999999999996, 0.013599999999999984),
#  (5.199999999999996, 0.013799999999999982),
#  (5.199999999999996, 0.013999999999999983),
#  (5.199999999999996, 0.014199999999999983),
#  (5.199999999999996, 0.014399999999999982),
#  (5.299999999999995, 0.004),
#  (5.299999999999995, 0.0042),
#  (5.299999999999995, 0.004399999999999999),
#  (5.299999999999995, 0.004599999999999999),
#  (5.299999999999995, 0.004799999999999999),
#  (5.299999999999995, 0.004999999999999998),
#  (5.299999999999995, 0.005199999999999998),
#  (5.299999999999995, 0.005399999999999998),
#  (5.299999999999995, 0.005599999999999997),
#  (5.299999999999995, 0.005799999999999997),
#  (5.299999999999995, 0.005999999999999997),
#  (5.299999999999995, 0.006199999999999996),
#  (5.299999999999995, 0.006399999999999996),
#  (5.299999999999995, 0.006599999999999996),
#  (5.299999999999995, 0.006799999999999995),
#  (5.299999999999995, 0.006999999999999995),
#  (5.299999999999995, 0.007199999999999995),
#  (5.299999999999995, 0.007399999999999994),
#  (5.299999999999995, 0.007599999999999994),
#  (5.299999999999995, 0.007799999999999994),
#  (5.299999999999995, 0.007999999999999993),
#  (5.299999999999995, 0.008199999999999992),
#  (5.299999999999995, 0.008399999999999993),
#  (5.299999999999995, 0.008599999999999993),
#  (5.299999999999995, 0.008799999999999992),
#  (5.299999999999995, 0.00899999999999999),
#  (5.299999999999995, 0.009199999999999991),
#  (5.299999999999995, 0.009399999999999992),
#  (5.299999999999995, 0.00959999999999999),
#  (5.299999999999995, 0.00979999999999999),
#  (5.299999999999995, 0.00999999999999999),
#  (5.299999999999995, 0.01019999999999999),
#  (5.299999999999995, 0.010399999999999989),
#  (5.299999999999995, 0.010599999999999988),
#  (5.299999999999995, 0.010799999999999988),
#  (5.299999999999995, 0.010999999999999989),
#  (5.299999999999995, 0.011199999999999988),
#  (5.299999999999995, 0.011399999999999987),
#  (5.299999999999995, 0.011599999999999987),
#  (5.299999999999995, 0.011799999999999988),
#  (5.299999999999995, 0.011999999999999986),
#  (5.299999999999995, 0.012199999999999985),
#  (5.299999999999995, 0.012399999999999986),
#  (5.299999999999995, 0.012599999999999986),
#  (5.299999999999995, 0.012799999999999985),
#  (5.299999999999995, 0.012999999999999984),
#  (5.299999999999995, 0.013199999999999984),
#  (5.299999999999995, 0.013399999999999985),
#  (5.299999999999995, 0.013599999999999984),
#  (5.299999999999995, 0.013799999999999982),
#  (5.299999999999995, 0.013999999999999983),
#  (5.299999999999995, 0.014199999999999983),
#  (5.299999999999995, 0.014399999999999982),
#  (5.299999999999995, 0.014599999999999981),
#  (5.299999999999995, 0.014799999999999982),
#  (5.399999999999995, 0.004),
#  (5.399999999999995, 0.0042),
#  (5.399999999999995, 0.004399999999999999),
#  (5.399999999999995, 0.004599999999999999),
#  (5.399999999999995, 0.004799999999999999),
#  (5.399999999999995, 0.004999999999999998),
#  (5.399999999999995, 0.005199999999999998),
#  (5.399999999999995, 0.005399999999999998),
#  (5.399999999999995, 0.005599999999999997),
#  (5.399999999999995, 0.005799999999999997),
#  (5.399999999999995, 0.005999999999999997),
#  (5.399999999999995, 0.006199999999999996),
#  (5.399999999999995, 0.006399999999999996),
#  (5.399999999999995, 0.006599999999999996),
#  (5.399999999999995, 0.006799999999999995),
#  (5.399999999999995, 0.006999999999999995),
#  (5.399999999999995, 0.007199999999999995),
#  (5.399999999999995, 0.007399999999999994),
#  (5.399999999999995, 0.007599999999999994),
#  (5.399999999999995, 0.007799999999999994),
#  (5.399999999999995, 0.007999999999999993),
#  (5.399999999999995, 0.008199999999999992),
#  (5.399999999999995, 0.008399999999999993),
#  (5.399999999999995, 0.008599999999999993),
#  (5.399999999999995, 0.008799999999999992),
#  (5.399999999999995, 0.00899999999999999),
#  (5.399999999999995, 0.009199999999999991),
#  (5.399999999999995, 0.009399999999999992),
#  (5.399999999999995, 0.00959999999999999),
#  (5.399999999999995, 0.00979999999999999),
#  (5.399999999999995, 0.00999999999999999),
#  (5.399999999999995, 0.01019999999999999),
#  (5.399999999999995, 0.010399999999999989),
#  (5.399999999999995, 0.010599999999999988),
#  (5.399999999999995, 0.010799999999999988),
#  (5.399999999999995, 0.010999999999999989),
#  (5.399999999999995, 0.011199999999999988),
#  (5.399999999999995, 0.011399999999999987),
#  (5.399999999999995, 0.011599999999999987),
#  (5.399999999999995, 0.011799999999999988),
#  (5.399999999999995, 0.011999999999999986),
#  (5.399999999999995, 0.012199999999999985),
#  (5.399999999999995, 0.012399999999999986),
#  (5.399999999999995, 0.012599999999999986),
#  (5.399999999999995, 0.012799999999999985),
#  (5.399999999999995, 0.012999999999999984),
#  (5.399999999999995, 0.013199999999999984),
#  (5.399999999999995, 0.013399999999999985),
#  (5.399999999999995, 0.013599999999999984),
#  (5.399999999999995, 0.013799999999999982),
#  (5.399999999999995, 0.013999999999999983),
#  (5.399999999999995, 0.014199999999999983),
#  (5.399999999999995, 0.014399999999999982),
#  (5.399999999999995, 0.014599999999999981),
#  (5.399999999999995, 0.014799999999999982),
#  (5.399999999999995, 0.014999999999999982),
#  (5.499999999999995, 0.004799999999999999),
#  (5.499999999999995, 0.004999999999999998),
#  (5.499999999999995, 0.005199999999999998),
#  (5.499999999999995, 0.005399999999999998),
#  (5.499999999999995, 0.005599999999999997),
#  (5.499999999999995, 0.005799999999999997),
#  (5.499999999999995, 0.005999999999999997),
#  (5.499999999999995, 0.006199999999999996),
#  (5.499999999999995, 0.006399999999999996),
#  (5.499999999999995, 0.006599999999999996),
#  (5.499999999999995, 0.006799999999999995),
#  (5.499999999999995, 0.006999999999999995),
#  (5.499999999999995, 0.007199999999999995),
#  (5.499999999999995, 0.007399999999999994),
#  (5.499999999999995, 0.007599999999999994),
#  (5.499999999999995, 0.007799999999999994),
#  (5.499999999999995, 0.007999999999999993),
#  (5.499999999999995, 0.008199999999999992),
#  (5.499999999999995, 0.008399999999999993),
#  (5.499999999999995, 0.008599999999999993),
#  (5.499999999999995, 0.008799999999999992),
#  (5.499999999999995, 0.00899999999999999),
#  (5.499999999999995, 0.009199999999999991),
#  (5.499999999999995, 0.009399999999999992),
#  (5.499999999999995, 0.00959999999999999),
#  (5.499999999999995, 0.00979999999999999),
#  (5.499999999999995, 0.00999999999999999),
#  (5.499999999999995, 0.01019999999999999),
#  (5.499999999999995, 0.010399999999999989),
#  (5.499999999999995, 0.010599999999999988),
#  (5.499999999999995, 0.010799999999999988),
#  (5.499999999999995, 0.010999999999999989),
#  (5.499999999999995, 0.011199999999999988),
#  (5.499999999999995, 0.011399999999999987),
#  (5.499999999999995, 0.011599999999999987),
#  (5.499999999999995, 0.011799999999999988),
#  (5.499999999999995, 0.011999999999999986),
#  (5.499999999999995, 0.012199999999999985),
#  (5.499999999999995, 0.012399999999999986),
#  (5.499999999999995, 0.012599999999999986),
#  (5.499999999999995, 0.012799999999999985),
#  (5.499999999999995, 0.012999999999999984),
#  (5.499999999999995, 0.013199999999999984),
#  (5.499999999999995, 0.013399999999999985),
#  (5.499999999999995, 0.013599999999999984),
#  (5.499999999999995, 0.013799999999999982),
#  (5.499999999999995, 0.013999999999999983),
#  (5.499999999999995, 0.014199999999999983),
#  (5.499999999999995, 0.014399999999999982),
#  (5.499999999999995, 0.014599999999999981),
#  (5.499999999999995, 0.014799999999999982),
#  (5.499999999999995, 0.014999999999999982),
#  (5.599999999999994, 0.006599999999999996),
#  (5.599999999999994, 0.006799999999999995),
#  (5.599999999999994, 0.006999999999999995),
#  (5.599999999999994, 0.007199999999999995),
#  (5.599999999999994, 0.007399999999999994),
#  (5.599999999999994, 0.007599999999999994),
#  (5.599999999999994, 0.007799999999999994),
#  (5.599999999999994, 0.007999999999999993),
#  (5.599999999999994, 0.008199999999999992),
#  (5.599999999999994, 0.008399999999999993),
#  (5.599999999999994, 0.008599999999999993),
#  (5.599999999999994, 0.008799999999999992),
#  (5.599999999999994, 0.00899999999999999),
#  (5.599999999999994, 0.009199999999999991),
#  (5.599999999999994, 0.009399999999999992),
#  (5.599999999999994, 0.00959999999999999),
#  (5.599999999999994, 0.00979999999999999),
#  (5.599999999999994, 0.00999999999999999),
#  (5.599999999999994, 0.01019999999999999),
#  (5.599999999999994, 0.010399999999999989),
#  (5.599999999999994, 0.010599999999999988),
#  (5.599999999999994, 0.010799999999999988),
#  (5.599999999999994, 0.010999999999999989),
#  (5.599999999999994, 0.011199999999999988),
#  (5.599999999999994, 0.011399999999999987),
#  (5.599999999999994, 0.011599999999999987),
#  (5.599999999999994, 0.011799999999999988),
#  (5.599999999999994, 0.011999999999999986),
#  (5.599999999999994, 0.012199999999999985),
#  (5.599999999999994, 0.012399999999999986),
#  (5.599999999999994, 0.012599999999999986),
#  (5.599999999999994, 0.012799999999999985),
#  (5.599999999999994, 0.012999999999999984),
#  (5.599999999999994, 0.013199999999999984),
#  (5.599999999999994, 0.013399999999999985),
#  (5.599999999999994, 0.013599999999999984),
#  (5.599999999999994, 0.013799999999999982),
#  (5.599999999999994, 0.013999999999999983),
#  (5.599999999999994, 0.014199999999999983),
#  (5.599999999999994, 0.014399999999999982),
#  (5.599999999999994, 0.014599999999999981),
#  (5.599999999999994, 0.014799999999999982),
#  (5.599999999999994, 0.014999999999999982),
#  (5.699999999999994, 0.008399999999999993),
#  (5.699999999999994, 0.008599999999999993),
#  (5.699999999999994, 0.008799999999999992),
#  (5.699999999999994, 0.00899999999999999),
#  (5.699999999999994, 0.009199999999999991),
#  (5.699999999999994, 0.009399999999999992),
#  (5.699999999999994, 0.00959999999999999),
#  (5.699999999999994, 0.00979999999999999),
#  (5.699999999999994, 0.00999999999999999),
#  (5.699999999999994, 0.01019999999999999),
#  (5.699999999999994, 0.010399999999999989),
#  (5.699999999999994, 0.010599999999999988),
#  (5.699999999999994, 0.010799999999999988),
#  (5.699999999999994, 0.010999999999999989),
#  (5.699999999999994, 0.011199999999999988),
#  (5.699999999999994, 0.011399999999999987),
#  (5.699999999999994, 0.011599999999999987),
#  (5.699999999999994, 0.011799999999999988),
#  (5.699999999999994, 0.011999999999999986),
#  (5.699999999999994, 0.012199999999999985),
#  (5.699999999999994, 0.012399999999999986),
#  (5.699999999999994, 0.012599999999999986),
#  (5.699999999999994, 0.012799999999999985),
#  (5.699999999999994, 0.012999999999999984),
#  (5.699999999999994, 0.013199999999999984),
#  (5.699999999999994, 0.013399999999999985),
#  (5.699999999999994, 0.013599999999999984),
#  (5.699999999999994, 0.013799999999999982),
#  (5.699999999999994, 0.013999999999999983),
#  (5.699999999999994, 0.014199999999999983),
#  (5.699999999999994, 0.014399999999999982),
#  (5.699999999999994, 0.014599999999999981),
#  (5.699999999999994, 0.014799999999999982),
#  (5.699999999999994, 0.014999999999999982)]

# %%
from IPython.display import IFrame

# A bad opacity relation:

IFrame("Figures/bad_OR_example.pdf", width=600, height=600)
# Out:
#         <iframe
#             width="600"
#             height="600"
#             src="Figures/bad_OR_example.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Note the Y-axis is the expected transmission from the CSO interactive plotter minus the calculated transmission from the header information (WVMTAU and Airmass) and the given "a" and "b" values. I would expect a choice of "a" and "b" that returns "realistic" transmission values (those close to the transmission values calculated by the CSO interactive plotter). The Y-axis is in percent (since transmission is in percent). I would expect values to lay within +/- 5% of the CSO calculations. Therefore, the selected "a" and "b" values above are "not realistic" whereas the selected "a" and "b" values below are "realistic" for Maunakea.

# %%
from IPython.display import IFrame

# A good opacity relation (the points outside of the 0.05 "physical" threshold
# are in extremely good grade 1 weather at a low Airmass):

IFrame("Figures/good_OR_example.pdf", width=600, height=600)
# Out:
#         <iframe
#             width="600"
#             height="600"
#             src="Figures/good_OR_example.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Deriving the Optimal Opacity relation at Each Wavelength
#
# Now that I had a set of plausible set of physical opacity relations (pairs of "a" and "b" values which reproduced the CSO's  model Maunakea transmission for a given tau x airmass), it was time to find the optimal physical (a,b) combination that lead to the flattest Peak Flux and Total Flux versus Transmission curves.
#
# I selected 3 main sources for this analysis:
#
# 1. Uranus
# 1. CRL618
# 1. CRL2688
#
# Along with the less reliable
#
# 1. Mars
# 1. Neptune
#
# I also looked at several different regimes:
#
# 1. The 20110501 - 20120601 Era from Dempsey et al. 2013
# 1. The 20120601 - 20150127 Era with the Silver WVM
# 1. The 20150127 - 20150410 Era with no reliable JCMT WVM
# 1. The 20150410 - 20161116 Era with the Black WVM
# 1. The 20161116 - 20171206 Era with the Black WVM and the New Filters
# 1. The 20171206 - 20180111 Era with the removal of the goretex membrane
# 1. The 20180111 - 20180501 Post membrane Replacement to SMU Maintenance
# 1. The 20180501 - 20180630 Post SMU Maintenance to SMU Gain fix (halfway through night of 20180630 - see obs log)
# 1. The 20180630 - Present era.
#
# The next code, `TauRelPipeline_NOEXT.py` relies on a variety of programs found in the `TauRelPrepFunctions.py` and `TauRelAnalysis_20171215.py` packages (also `get_noext_reductions_from_kamaka.py`, coded with Graham's help). The first has functions that crop images, find files, etc while the second one has functions which can read fits headers using .sdf file format and perform general analysis like running KAPPA's beamfit.
#
# This code relies on a consistent reduction being performed nightly. Currently, there is a kamaka code that takes all the calibrator data and reduces it on 1 arcsecond pixels with NO EXTINCTION CORRECTION. The data is in pW and it has no extinction correction applied
#
# This is the order of operations for `TauRelPipeline_NOEXT.py`:
#
# 1. Gather the reduced data that has no extinction correction or FCF factor applied
# 1. Select, from those, the source you are currently interested in
# 1. Construct the Transmission versus PWV function as before
# 1. For each pair of physical coefficients (a,b) and each calibrator observation:
#
#     1. Get the tau225 from the header by averaging WVMTAUST and WVMTAUEN
#     1. Get the airmass from the header, again by averaging AMSTART and AMEND over the short observation
#     1. Calculate the transmission and compare it to the expected transmission
#     1. Apply the new extinction correction (transmission) using CMULT
#     1. Crop the image in order to run GaussClumps
#     1. Fit the peak flux with GaussClumps and obtain the size & area of the calibrator
#     1. Lay down a 1 arcminute diameter aperture centered on the calibrator and integrate the total flux
#
# 1. Save all the information for every (a,b) pair (size, location, peak flux, total flux, metadata, etc.)
# 1. Plot the Peak Flux versus Transmission for every calibrator observation and for every (a,b) extinction correction and fit a linear regression
# 1. Plot the Total Flux versus Transmission for every calibrator observation and for every (a,b) extinction correction and fit a linear regression
# 1. Find the shallowest slopes = the optimal (a,b)
#
# Run the above for every source, both wavelengths, and both regimes

# %%
# Gather information on the peaks/total fluxes/ transmissions, etc. for all physical (a,b) coefficients
# for all the sources, both wavelengths, both regimes. Each of these
# produce a dictionary of timestamped results in a directory called "results"

# THIS TAKES A LONG TIME if run from scratch (typically 1-3 hours for each file run) 
# Each function call is specially set up to run a few optimal physical opacity relations
# I've run several more than I am presenting here, on finer grids, but these relations show you
# basically what is happening if we alter the a and b coefficients of the opacity relation.

#Lines that are commented out twice: ##, indicate instances where the pipeline is run on several different
#opacity relations at each wavelength. Single commented lines: #, run the pipeline for either 1 or 2
#optimal opacity relations derived from previous work. 

#############################
#############################
#############################
# YOU SHOULD ONLY EVER HAVE TO RUN THE UNCOMMENTED LINES FOR THE PRESENT EPOCH (which can be updated each day). 
# THE REST OF THE RESULTS HAVE ALREADY BEEN OBTAINED AND PLACED IN THE "results/" DIRECTORY.
#############################
#############################
#############################

from TauRelPipeline_NOEXT_faster import TauRelPipeline

######
# Dempsey Era: 20110501 -> 20120531
######                             

# 450

##TauRelPipeline('CRL2688',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20110501','20120601')
##TauRelPipeline('CRL618',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20110501','20120601') 
##TauRelPipeline('URANUS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20110501','20120601') 
##TauRelPipeline('MARS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20110501','20120601')   
###TauRelPipeline('ARP220',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20110501','20120601') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20110501','20120601')
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20110501','20120601') 
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20110501','20120601') 
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20110501','20120601')
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20110501','20120601')
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20110501','20120601')

# 850

##TauRelPipeline('CRL2688',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20110501','20120601')
##TauRelPipeline('CRL618',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20110501','20120601') 
##TauRelPipeline('URANUS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20110501','20120601') 
##TauRelPipeline('MARS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20110501','20120601')   
###TauRelPipeline('ARP220',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20110501','20120601') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20110501','20120601')
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20110501','20120601') 
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20110501','20120601') 
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20110501','20120601')
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20110501','20120601')
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20110501','20120601')

######
# Silver WVM (Done in 2 chunks because of processing time) - 20120601 -> 20131231
######                                                    

# 450

##TauRelPipeline('CRL2688',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20120601','20140101')
##TauRelPipeline('CRL618',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20120601','20140101') 
##TauRelPipeline('URANUS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20120601','20140101') 
##TauRelPipeline('MARS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20120601','20140101')   
###TauRelPipeline('ARP220',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20120601','20140101') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20120601','20140101')
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20120601','20140101') 
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20120601','20140101') 
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20120601','20140101')
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20120601','20140101')
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20120601','20140101')

##TauRelPipeline('CRL2688',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20140101','20150127')
##TauRelPipeline('CRL618',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20140101','20150127') 
##TauRelPipeline('URANUS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20140101','20150127') 
##TauRelPipeline('MARS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20140101','20150127')   
###TauRelPipeline('ARP220',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20140101','20150127') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20140101','20150127')
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20140101','20150127') 
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20140101','20150127') 
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20140101','20150127')
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20140101','20150127')
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20140101','20150127')

# 850

##TauRelPipeline('CRL2688',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20120601','20140101')
##TauRelPipeline('CRL618',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20120601','20140101') 
##TauRelPipeline('URANUS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20120601','20140101') 
##TauRelPipeline('MARS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20120601','20140101')   
###TauRelPipeline('ARP220',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20120601','20140101') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20120601','20140101')
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20120601','20140101') 
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20120601','20140101') 
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20120601','20140101') 
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20120601','20140101') 
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20120601','20140101')

##TauRelPipeline('CRL2688',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20140101','20150127')
##TauRelPipeline('CRL618',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20140101','20150127') 
##TauRelPipeline('URANUS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20140101','20150127') 
##TauRelPipeline('MARS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20140101','20150127')   
###TauRelPipeline('ARP220',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20140101','20150127') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20140101','20150127')
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20140101','20150127') 
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20140101','20150127') 
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20140101','20150127')
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20140101','20150127')
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20140101','20150127')

######
# No Reliable WVM - 20150127 -> 20150409
######           

# 450

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20150127','20150410') 
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20150127','20150410')  
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20150127','20150410')  
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20150127','20150410')    
##TauRelPipeline('ARP220',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20150127','20150410') # Processing issues on kamaka
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20150127','20150410')
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20150127','20150410')


# 850

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20150127','20150410')
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20150127','20150410')
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20150127','20150410')
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20150127','20150410')
##TauRelPipeline('ARP220',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20150127','20150410') # Processing issues on kamaka
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20150127','20150410')
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20150127','20150410')

######
# Black WVM, old SCUBA-2 Filters - 20150410 -> 20161031
######

# 450

##TauRelPipeline('CRL2688',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20150410','20161101')
##TauRelPipeline('CRL618',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20150410','20161101')
##TauRelPipeline('URANUS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20150410','20161101')
##TauRelPipeline('MARS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20150410','20161101')
###TauRelPipeline('ARP220',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20150410','20161101') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20150410','20161101')
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20150410','20161101')
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20150410','20161101')
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20150410','20161101')
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20150410','20161101')
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20150410','20161101')

# 850

##TauRelPipeline('CRL2688',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')
##TauRelPipeline('CRL618',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')
##TauRelPipeline('URANUS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')
##TauRelPipeline('MARS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')
###TauRelPipeline('ARP220',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20150410','20161101') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20150410','20161101')

#######
# New SCUBA-2 Filters (20161101) to present (includes membrane removal and replacement) - 20161101 -> 20171205
#######

# 450

##TauRelPipeline('CRL2688',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20161101','20171206') 
##TauRelPipeline('CRL618',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20161101','20171206') 
##TauRelPipeline('URANUS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20161101','20171206')  
##TauRelPipeline('MARS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20161101','20171206')  
###TauRelPipeline('ARP220',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20161101','20171206') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20161101','20171206') 
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20161101','20171206') 
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20161101','20171206')  
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20161101','20171206')
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20161101','20171206')
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20161101','20171206')

# 850

##TauRelPipeline('CRL2688',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20161101','20171206')  
##TauRelPipeline('CRL618',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20161101','20171206')  
##TauRelPipeline('URANUS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20161101','20171206')  
##TauRelPipeline('MARS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20161101','20171206') 
###TauRelPipeline('ARP220',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20161101','20171206') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20161101','20171206')  
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20161101','20171206')  
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20161101','20171206')  
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20161101','20171206') 
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20161101','20171206')
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20161101','20171206')

#######
# Goretex removal to Goretex Replacement - 20171206 -> 20180110 
#######

# 450

##TauRelPipeline('CRL2688',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20171206','20180111')  
##TauRelPipeline('CRL618',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20171206','20180111')  
##TauRelPipeline('URANUS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20171206','20180111')  
##TauRelPipeline('MARS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20171206','20180111')  
###TauRelPipeline('ARP220',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20171206','20180111') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20171206','20180111')  
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20171206','20180111')  
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20171206','20180111')  
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20171206','20180111') 
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20171206','20180111')
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20171206','20180111')

# 850

##TauRelPipeline('CRL2688',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20171206','20180111')  
##TauRelPipeline('CRL618',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20171206','20180111')  
##TauRelPipeline('URANUS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20171206','20180111')  
##TauRelPipeline('MARS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20171206','20180111') 
###TauRelPipeline('ARP220',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20171206','20180111') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20171206','20180111')  
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20171206','20180111')  
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20171206','20180111')  
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20171206','20180111') 
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20171206','20180111')
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20171206','20180111')

#######
# Goretex Replacement to May 2018 Shutdown - 20180111 -> 20180430
#######

# 450

##TauRelPipeline('CRL2688',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180111','20180501') # LAST RUN 20180423
##TauRelPipeline('CRL618',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180111','20180501') # LAST RUN 20180423
##TauRelPipeline('URANUS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180111','20180501') # LAST RUN 20180423
##TauRelPipeline('MARS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180111','20180501') # LAST RUN 20180423
###TauRelPipeline('ARP220',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180111','20180501') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20180111','20180501') # LAST RUN 20180430 (No data 20180430)
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20180111','20180501') # LAST RUN 20180430
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20180111','20180501') # LAST RUN 20180430
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20180111','20180501') # LAST RUN 20180430
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20180111','20180501')
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20180111','20180501')

# 850

##TauRelPipeline('CRL2688',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180111','20180501') # LAST RUN 20180423
##TauRelPipeline('CRL618',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180111','20180501') # LAST RUN 20180423
##TauRelPipeline('URANUS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180111','20180501') # LAST RUN 20180423
##TauRelPipeline('MARS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180111','20180501') # LAST RUN 20180423
###TauRelPipeline('ARP220',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180111','20180501') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20180111','20180501') # LAST RUN 20180430 (No data 20180430)
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20180111','20180501') # LAST RUN 20180430
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20180111','20180501') # LAST RUN 20180430
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20180111','20180501') # LAST RUN 20180430
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20180111','20180501')
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20180111','20180501')

#######
# May 2018 Shutdown to SMU gain Fix - 20180501 -> 20180629
#######

# 450

##TauRelPipeline('CRL2688',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180501','25001231') # LAST RUN Never
##TauRelPipeline('CRL618',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180501','25001231') # LAST RUN Never
##TauRelPipeline('URANUS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180501','25001231') # LAST RUN Never
##TauRelPipeline('MARS',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180501','25001231') # LAST RUN Never
###TauRelPipeline('ARP220',[(19.5, 0.006), (23.0, 0.008), (26.0, 0.012)],'450','20180501','25001231') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20180501','20180630')

# 850

##TauRelPipeline('CRL2688',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180501','25001231') # LAST RUN Never
##TauRelPipeline('CRL618',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180501','25001231') # LAST RUN Never
##TauRelPipeline('URANUS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180501','25001231') # LAST RUN Never
##TauRelPipeline('MARS',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180501','25001231') # LAST RUN Never
###TauRelPipeline('ARP220',[(4.3, 0.0040), (4.6,0.0043),(5.5,0.013)],'850','20180501','25001231') # Processing issues on kamaka

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20180501','20180630') # LAST RUN 20180705
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20180501','20180630')

#######
# SMU Gain Fix to Goretex Membrane Off for more Permanent SMU Fix - 20180630 -> 20180724
#######

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20180630','20180724')

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20180630','20180724') # LAST RUN 20180725
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20180630','20180724')

#######
# Goretex Membrane Off for more Permanent SMU Fix - Warm up for HELCO outage -- 20180725 -> 20181126
#######

#TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('MARS',[(26.0, 0.012)],'450','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20180724','20181126')

#TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20180724','20181126') # LAST RUN 20181128
#TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20180724','20181126')


#######
# Cool Down after HELCO outage - Present -- 20181203 -> Present
#######

TauRelPipeline('CRL2688',[(26.0, 0.012)],'450','20181126','25001230') # LAST RUN 20190819
TauRelPipeline('CRL618',[(26.0, 0.012)],'450','20181126','25001230') # LAST RUN 20190819
TauRelPipeline('URANUS',[(26.0, 0.012)],'450','20181126','25001230') # LAST RUN 20190819
TauRelPipeline('MARS',[(26.0, 0.012)],'450','20181126','25001230') # LAST RUN 20190819
#TauRelPipeline('NEPTUNE',[(26.0, 0.012)],'450','20181126','25001230') # LAST RUN 20190819
TauRelPipeline('Arp220',[(26.0, 0.012)],'450','20181126','25001230') # LAST RUN 20190819

TauRelPipeline('CRL2688',[(4.6,0.0043),(5.5,0.013)],'850','20181126','25001230') # LAST RUN 20190819
TauRelPipeline('CRL618',[(4.6,0.0043),(5.5,0.013)],'850','20181126','25001230') # LAST RUN 20190819
TauRelPipeline('URANUS',[(4.6,0.0043),(5.5,0.013)],'850','20181126','25001230') # LAST RUN 20190819
TauRelPipeline('MARS',[(4.6,0.0043),(5.5,0.013)],'850','20181126','25001230') # LAST RUN 20190819
#TauRelPipeline('NEPTUNE',[(4.6,0.0043),(5.5,0.013)],'850','20181126','25001230') # LAST RUN 20190819
TauRelPipeline('Arp220',[(4.6,0.0043),(5.5,0.013)],'850','20181126','25001230') # LAST RUN 20190819
# Out:
# ##############
# ##############
# ##############
# ### Beginning ###
# ##############
# ##############
# ##############
#
# ##############
# ##############
# ##############
# ### "Gathering list of NOEXT, UNCALIBRATED Files" ###
# ##############
# ##############
# ##############
#
# ##############
# ##############
# ##############
# ### "List of files has been gathered!" ###
# ##############
# ##############
# ##############
#
# ##############
# ##############
# ##############
# ### Building Transmission vs PWV function
# ##############
# ##############
# ##############
#
# ##############
# ##############
# ##############
# ### Testing Pairs of Coefficients for the Tau Relation
# ##############
# ##############
# ##############
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ######
# # Pair 1 out of 1
# ######
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236241/s20181203_00018_450_reduced.sdf (1 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236241/s20181203_00017_450_reduced.sdf (2 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236323/s20181205_00016_450_reduced.sdf (3 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236323/s20181205_00007_450_reduced.sdf (4 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236360/s20181206_00009_450_reduced.sdf (5 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236360/s20181206_00015_450_reduced.sdf (6 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236409/s20181207_00008_450_reduced.sdf (7 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236464/s20181208_00009_450_reduced.sdf (8 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236513/s20181209_00007_450_reduced.sdf (9 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236569/s20181210_00007_450_reduced.sdf (10 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236569/s20181210_00016_450_reduced.sdf (11 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236612/s20181211_00018_450_reduced.sdf (12 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236655/s20181212_00007_450_reduced.sdf (13 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000236/000236977/s20181221_00011_450_reduced.sdf (14 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237005/s20181222_00008_450_reduced.sdf (15 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237052/s20181223_00012_450_reduced.sdf (16 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237144/s20181224_00010_450_reduced.sdf (17 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237311/s20190101_00009_450_reduced.sdf (18 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237383/s20190102_00007_450_reduced.sdf (19 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237447/s20190103_00010_450_reduced.sdf (20 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237490/s20190104_00007_450_reduced.sdf (21 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237537/s20190105_00010_450_reduced.sdf (22 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237585/s20190106_00007_450_reduced.sdf (23 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237642/s20190107_00007_450_reduced.sdf (24 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237730/s20190109_00081_450_reduced.sdf (25 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000237/000237866/s20190112_00078_450_reduced.sdf (26 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000238/000238034/s20190115_00077_450_reduced.sdf (27 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000238/000238146/s20190117_00080_450_reduced.sdf (28 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000238/000238316/s20190121_00055_450_reduced.sdf (29 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000238/000238316/s20190121_00066_450_reduced.sdf (30 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000238/000238316/s20190121_00061_450_reduced.sdf (31 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000238/000238362/s20190122_00066_450_reduced.sdf (32 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000238/000238903/s20190217_00030_450_reduced.sdf (33 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000238/000238936/s20190218_00038_450_reduced.sdf (34 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239001/s20190225_00060_450_reduced.sdf (35 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239057/s20190226_00068_450_reduced.sdf (36 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239057/s20190226_00079_450_reduced.sdf (37 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239057/s20190226_00084_450_reduced.sdf (38 out of 294)
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239057/s20190226_00073_450_reduced.sdf (39 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239097/s20190228_00057_450_reduced.sdf (40 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239097/s20190228_00059_450_reduced.sdf (41 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239178/s20190302_00066_450_reduced.sdf (42 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239178/s20190302_00081_450_reduced.sdf (43 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239178/s20190302_00074_450_reduced.sdf (44 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239178/s20190302_00054_450_reduced.sdf (45 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239227/s20190303_00054_450_reduced.sdf (46 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239288/s20190304_00055_450_reduced.sdf (47 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239288/s20190304_00092_450_reduced.sdf (48 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239288/s20190304_00075_450_reduced.sdf (49 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239326/s20190305_00056_450_reduced.sdf (50 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239374/s20190306_00076_450_reduced.sdf (51 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239374/s20190306_00073_450_reduced.sdf (52 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239496/s20190309_00085_450_reduced.sdf (53 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239496/s20190309_00079_450_reduced.sdf (54 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239575/s20190310_00069_450_reduced.sdf (55 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239680/s20190312_00071_450_reduced.sdf (56 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239680/s20190312_00063_450_reduced.sdf (57 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239730/s20190313_00068_450_reduced.sdf (58 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239788/s20190314_00071_450_reduced.sdf (59 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239788/s20190314_00081_450_reduced.sdf (60 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239788/s20190314_00063_450_reduced.sdf (61 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239849/s20190315_00059_450_reduced.sdf (62 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239849/s20190315_00065_450_reduced.sdf (63 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239849/s20190315_00071_450_reduced.sdf (64 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239899/s20190316_00068_450_reduced.sdf (65 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239945/s20190317_00069_450_reduced.sdf (66 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239986/s20190318_00059_450_reduced.sdf (67 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239986/s20190318_00070_450_reduced.sdf (68 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239986/s20190318_00083_450_reduced.sdf (69 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000239/000239986/s20190318_00076_450_reduced.sdf (70 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240037/s20190319_00076_450_reduced.sdf (71 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240037/s20190319_00082_450_reduced.sdf (72 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240037/s20190319_00066_450_reduced.sdf (73 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240091/s20190320_00096_450_reduced.sdf (74 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240091/s20190320_00077_450_reduced.sdf (75 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240091/s20190320_00086_450_reduced.sdf (76 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240153/s20190321_00077_450_reduced.sdf (77 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240153/s20190321_00083_450_reduced.sdf (78 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240153/s20190321_00088_450_reduced.sdf (79 out of 294)
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000240/000240201/s20190322_00072_450_reduced.sdf (80 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243676/s20190323_00078_450_reduced.sdf (81 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243736/s20190324_00074_450_reduced.sdf (82 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243736/s20190324_00069_450_reduced.sdf (83 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243736/s20190324_00108_450_reduced.sdf (84 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243736/s20190324_00080_450_reduced.sdf (85 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243736/s20190324_00102_450_reduced.sdf (86 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243736/s20190324_00095_450_reduced.sdf (87 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243803/s20190325_00067_450_reduced.sdf (88 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243803/s20190325_00081_450_reduced.sdf (89 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243803/s20190325_00062_450_reduced.sdf (90 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243883/s20190326_00063_450_reduced.sdf (91 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243883/s20190326_00072_450_reduced.sdf (92 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243883/s20190326_00055_450_reduced.sdf (93 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243883/s20190326_00090_450_reduced.sdf (94 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243941/s20190327_00065_450_reduced.sdf (95 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243941/s20190327_00055_450_reduced.sdf (96 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243960/s20190328_00029_450_reduced.sdf (97 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000243/000243960/s20190328_00023_450_reduced.sdf (98 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244016/s20190329_00070_450_reduced.sdf (99 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244016/s20190329_00089_450_reduced.sdf (100 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244016/s20190329_00076_450_reduced.sdf (101 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244016/s20190329_00082_450_reduced.sdf (102 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244063/s20190330_00061_450_reduced.sdf (103 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244133/s20190331_00073_450_reduced.sdf (104 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244133/s20190331_00081_450_reduced.sdf (105 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244133/s20190331_00059_450_reduced.sdf (106 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244133/s20190331_00093_450_reduced.sdf (107 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244133/s20190331_00087_450_reduced.sdf (108 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244133/s20190331_00061_450_reduced.sdf (109 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244193/s20190402_00054_450_reduced.sdf (110 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244193/s20190402_00065_450_reduced.sdf (111 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244309/s20190404_00096_450_reduced.sdf (112 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244309/s20190404_00075_450_reduced.sdf (113 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244309/s20190404_00088_450_reduced.sdf (114 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244375/s20190405_00078_450_reduced.sdf (115 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244375/s20190405_00084_450_reduced.sdf (116 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244375/s20190405_00067_450_reduced.sdf (117 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244375/s20190405_00099_450_reduced.sdf (118 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244375/s20190405_00092_450_reduced.sdf (119 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244424/s20190406_00059_450_reduced.sdf (120 out of 294)
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244424/s20190406_00074_450_reduced.sdf (121 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244424/s20190406_00082_450_reduced.sdf (122 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244503/s20190407_00100_450_reduced.sdf (123 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244503/s20190407_00085_450_reduced.sdf (124 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244503/s20190407_00078_450_reduced.sdf (125 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244503/s20190407_00091_450_reduced.sdf (126 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244503/s20190407_00068_450_reduced.sdf (127 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244566/s20190408_00075_450_reduced.sdf (128 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244566/s20190408_00069_450_reduced.sdf (129 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244627/s20190409_00089_450_reduced.sdf (130 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244627/s20190409_00078_450_reduced.sdf (131 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244627/s20190409_00066_450_reduced.sdf (132 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244627/s20190409_00097_450_reduced.sdf (133 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244673/s20190410_00053_450_reduced.sdf (134 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244673/s20190410_00042_450_reduced.sdf (135 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244752/s20190415_00056_450_reduced.sdf (136 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244752/s20190415_00046_450_reduced.sdf (137 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244788/s20190416_00040_450_reduced.sdf (138 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244788/s20190416_00051_450_reduced.sdf (139 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244853/s20190418_00060_450_reduced.sdf (140 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244853/s20190418_00047_450_reduced.sdf (141 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244853/s20190418_00080_450_reduced.sdf (142 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244853/s20190418_00070_450_reduced.sdf (143 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244853/s20190418_00045_450_reduced.sdf (144 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244896/s20190419_00062_450_reduced.sdf (145 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244896/s20190419_00077_450_reduced.sdf (146 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244943/s20190420_00063_450_reduced.sdf (147 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244943/s20190420_00047_450_reduced.sdf (148 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245006/s20190421_00072_450_reduced.sdf (149 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245006/s20190421_00078_450_reduced.sdf (150 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245006/s20190421_00066_450_reduced.sdf (151 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245006/s20190421_00088_450_reduced.sdf (152 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245006/s20190421_00045_450_reduced.sdf (153 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245006/s20190421_00058_450_reduced.sdf (154 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245070/s20190422_00060_450_reduced.sdf (155 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245070/s20190422_00082_450_reduced.sdf (156 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245070/s20190422_00052_450_reduced.sdf (157 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245070/s20190422_00072_450_reduced.sdf (158 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245116/s20190423_00026_450_reduced.sdf (159 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245116/s20190423_00015_450_reduced.sdf (160 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245170/s20190424_00095_450_reduced.sdf (161 out of 294)
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245170/s20190424_00085_450_reduced.sdf (162 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245170/s20190424_00062_450_reduced.sdf (163 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245170/s20190424_00074_450_reduced.sdf (164 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245229/s20190425_00059_450_reduced.sdf (165 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245229/s20190425_00067_450_reduced.sdf (166 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245229/s20190425_00045_450_reduced.sdf (167 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245229/s20190425_00075_450_reduced.sdf (168 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245289/s20190426_00058_450_reduced.sdf (169 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245289/s20190426_00075_450_reduced.sdf (170 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245335/s20190427_00053_450_reduced.sdf (171 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245427/s20190501_00091_450_reduced.sdf (172 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245427/s20190501_00075_450_reduced.sdf (173 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245427/s20190501_00062_450_reduced.sdf (174 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245486/s20190502_00081_450_reduced.sdf (175 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245486/s20190502_00087_450_reduced.sdf (176 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245486/s20190502_00048_450_reduced.sdf (177 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245486/s20190502_00067_450_reduced.sdf (178 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245514/s20190503_00039_450_reduced.sdf (179 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245514/s20190503_00026_450_reduced.sdf (180 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245587/s20190507_00077_450_reduced.sdf (181 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245587/s20190507_00066_450_reduced.sdf (182 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245587/s20190507_00082_450_reduced.sdf (183 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245587/s20190507_00048_450_reduced.sdf (184 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245644/s20190508_00056_450_reduced.sdf (185 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245644/s20190508_00038_450_reduced.sdf (186 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245644/s20190508_00070_450_reduced.sdf (187 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245696/s20190509_00029_450_reduced.sdf (188 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245696/s20190509_00038_450_reduced.sdf (189 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245696/s20190509_00050_450_reduced.sdf (190 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245755/s20190510_00068_450_reduced.sdf (191 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245755/s20190510_00086_450_reduced.sdf (192 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245755/s20190510_00081_450_reduced.sdf (193 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245755/s20190510_00057_450_reduced.sdf (194 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245755/s20190510_00044_450_reduced.sdf (195 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245853/s20190512_00071_450_reduced.sdf (196 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245853/s20190512_00044_450_reduced.sdf (197 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245853/s20190512_00062_450_reduced.sdf (198 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245853/s20190512_00057_450_reduced.sdf (199 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245853/s20190512_00040_450_reduced.sdf (200 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245891/s20190513_00044_450_reduced.sdf (201 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245891/s20190513_00060_450_reduced.sdf (202 out of 294)
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245936/s20190514_00044_450_reduced.sdf (203 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245936/s20190514_00063_450_reduced.sdf (204 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245936/s20190514_00041_450_reduced.sdf (205 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245997/s20190517_00089_450_reduced.sdf (206 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245997/s20190517_00047_450_reduced.sdf (207 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245997/s20190517_00082_450_reduced.sdf (208 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245997/s20190517_00062_450_reduced.sdf (209 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245997/s20190517_00076_450_reduced.sdf (210 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246072/s20190519_00074_450_reduced.sdf (211 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246072/s20190519_00060_450_reduced.sdf (212 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246072/s20190519_00080_450_reduced.sdf (213 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246072/s20190519_00040_450_reduced.sdf (214 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246072/s20190519_00066_450_reduced.sdf (215 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246119/s20190520_00042_450_reduced.sdf (216 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246250/s20190524_00068_450_reduced.sdf (217 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246250/s20190524_00053_450_reduced.sdf (218 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246250/s20190524_00079_450_reduced.sdf (219 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246250/s20190524_00085_450_reduced.sdf (220 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246320/s20190525_00052_450_reduced.sdf (221 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246320/s20190525_00065_450_reduced.sdf (222 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246441/s20190526_00101_450_reduced.sdf (223 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246441/s20190526_00110_450_reduced.sdf (224 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246441/s20190526_00111_450_reduced.sdf (225 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246441/s20190526_00117_450_reduced.sdf (226 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246441/s20190526_00088_450_reduced.sdf (227 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246497/s20190527_00077_450_reduced.sdf (228 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246497/s20190527_00083_450_reduced.sdf (229 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246497/s20190527_00066_450_reduced.sdf (230 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246497/s20190527_00048_450_reduced.sdf (231 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246542/s20190528_00064_450_reduced.sdf (232 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246542/s20190528_00049_450_reduced.sdf (233 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246576/s20190529_00047_450_reduced.sdf (234 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246576/s20190529_00060_450_reduced.sdf (235 out of 294)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246613/s20190530_00056_450_reduced.sdf (236 out of 294)
#
#
#
# ...
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244308/s20190404_00057_850_reduced.sdf (135 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244374/s20190405_00051_850_reduced.sdf (136 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244374/s20190405_00035_850_reduced.sdf (137 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244425/s20190406_00041_850_reduced.sdf (138 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244425/s20190406_00027_850_reduced.sdf (139 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244502/s20190407_00047_850_reduced.sdf (140 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244502/s20190407_00033_850_reduced.sdf (141 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244567/s20190408_00034_850_reduced.sdf (142 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244567/s20190408_00049_850_reduced.sdf (143 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244626/s20190409_00049_850_reduced.sdf (144 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244672/s20190410_00021_850_reduced.sdf (145 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244707/s20190411_00018_850_reduced.sdf (146 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244753/s20190415_00029_850_reduced.sdf (147 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244789/s20190416_00028_850_reduced.sdf (148 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244789/s20190416_00017_850_reduced.sdf (149 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244852/s20190418_00023_850_reduced.sdf (150 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244852/s20190418_00022_850_reduced.sdf (151 out of 213)
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244897/s20190419_00032_850_reduced.sdf (152 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000244/000244942/s20190420_00033_850_reduced.sdf (153 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245007/s20190421_00035_850_reduced.sdf (154 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245071/s20190422_00033_850_reduced.sdf (155 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245117/s20190423_00007_850_reduced.sdf (156 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245171/s20190424_00040_850_reduced.sdf (157 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245228/s20190425_00025_850_reduced.sdf (158 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245288/s20190426_00036_850_reduced.sdf (159 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245336/s20190427_00029_850_reduced.sdf (160 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245426/s20190501_00041_850_reduced.sdf (161 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245487/s20190502_00030_850_reduced.sdf (162 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245513/s20190503_00010_850_reduced.sdf (163 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245588/s20190507_00029_850_reduced.sdf (164 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245645/s20190508_00008_850_reduced.sdf (165 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245645/s20190508_00025_850_reduced.sdf (166 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245697/s20190509_00007_850_reduced.sdf (167 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245697/s20190509_00021_850_reduced.sdf (168 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245754/s20190510_00032_850_reduced.sdf (169 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245789/s20190511_00021_850_reduced.sdf (170 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245854/s20190512_00030_850_reduced.sdf (171 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245890/s20190513_00025_850_reduced.sdf (172 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245937/s20190514_00031_850_reduced.sdf (173 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245937/s20190514_00028_850_reduced.sdf (174 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000245/000245996/s20190517_00029_850_reduced.sdf (175 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246022/s20190518_00008_850_reduced.sdf (176 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246071/s20190519_00025_850_reduced.sdf (177 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246120/s20190520_00016_850_reduced.sdf (178 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246120/s20190520_00029_850_reduced.sdf (179 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246178/s20190522_00032_850_reduced.sdf (180 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246251/s20190524_00031_850_reduced.sdf (181 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246321/s20190525_00032_850_reduced.sdf (182 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246440/s20190526_00060_850_reduced.sdf (183 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246496/s20190527_00027_850_reduced.sdf (184 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246543/s20190528_00033_850_reduced.sdf (185 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246577/s20190529_00030_850_reduced.sdf (186 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246612/s20190530_00018_850_reduced.sdf (187 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246673/s20190531_00032_850_reduced.sdf (188 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246761/s20190601_00044_850_reduced.sdf (189 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246761/s20190601_00026_850_reduced.sdf (190 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246818/s20190602_00032_850_reduced.sdf (191 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246944/s20190604_00032_850_reduced.sdf (192 out of 213)
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000246/000246972/s20190605_00013_850_reduced.sdf (193 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247062/s20190608_00019_850_reduced.sdf (194 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247092/s20190609_00008_850_reduced.sdf (195 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247160/s20190610_00008_850_reduced.sdf (196 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247160/s20190610_00019_850_reduced.sdf (197 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247214/s20190611_00026_850_reduced.sdf (198 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247251/s20190612_00021_850_reduced.sdf (199 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247341/s20190614_00022_850_reduced.sdf (200 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247372/s20190615_00009_850_reduced.sdf (201 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247456/s20190619_00007_850_reduced.sdf (202 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247482/s20190620_00009_850_reduced.sdf (203 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247586/s20190626_00021_850_reduced.sdf (204 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247586/s20190626_00008_850_reduced.sdf (205 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247606/s20190627_00011_850_reduced.sdf (206 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247796/s20190707_00008_850_reduced.sdf (207 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247831/s20190708_00011_850_reduced.sdf (208 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000247/000247956/s20190711_00008_850_reduced.sdf (209 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000248/000248009/s20190712_00011_850_reduced.sdf (210 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000248/000248062/s20190713_00038_850_reduced.sdf (211 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000248/000248842/s20190813_00008_850_reduced.sdf (212 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
#  File: /net/kamaka/export/data/jsa_proc/output/000/000248/000248885/s20190814_00009_850_reduced.sdf (213 out of 213)
#
#
#
# Beginning the Cropping Procedure Method = CIRCLE Radius = 200...
#
# 	Crop = Done
#
#
# 82.5252174337705 minutes to complete.

# %% [markdown]
# Now, find the optimal opacity relations from the information that was just gathered, above using the code
#
# `TauRelResults_clean.py`: This code constructs a class out of a supplied results dictionary so values can be accessed using "class.value" notation. It also adds time, weather, airmass, and size constraints to the data and fits the resulting flux versus transmission curves.

# %%
#import os
#from TauRelResults_clean import TauRelResults
#import pickle
#
## Get all the dictionaries that were just created:
#
#resultsdicts1 = os.listdir('results/')
#resultsdicts  = []
#for i in resultsdicts1:
#    if i[-4:] == '.bin':
#        resultsdicts.append(i)
#
## Set the constraints:
#
## The Pixel Size in arcseconds
#
#pix_size=1.0
#
## How different can the calculated transmission
## be from the CSO tranmission model and still
## by considered physical?
## This is: abs(Trans_calculated - Trans_predicted)
#
#unphys_limit   = 0.05 #physthresh # From before
#
## What is the maximum TAU225 opacity to consider?
#
#tau_cutoff     = 0.32
#
## What is the earliest time of night to
## include - IN UTC (21:00 HST = 07:00 UTC)
#
#evening_cutoff = 7  #:00 UTC = 21:00 HST
#
## What is the latest time of morning to
## include - IN UTC (05:00 HST = 15:00 UTC)
#
#morning_cutoff = 16 #:00 UTC = 06:00 HST
#
## Introduce an airmass threshold to mitigate
## the scatter in peak fluxes
#
#airmass_cutoff = 1.9
#
#
## Set up some empty arrays to track the 
## most optimal opacity relations over each epoch
## and for each wavelength
#
#include_sources_450=[]
#include_sources_850=[]
#
#BINFILES_450=[]
#BINFILES_850=[]
#
#BESTKEYS_450_eachsource=[]
#BESTKEYS_850_eachsource=[]
#
#EPOCHS_450 = []
#EPOCHS_850 = []
#
#
## Construct the CSO transmission model for each wavelength
#from TauRelAnalysis_20171215 import FitCSOTransvsPWVFast
#
#TransvsPWV450 = FitCSOTransvsPWV(int(450))
#TransvsPWV850 = FitCSOTransvsPWV(int(850))
#
## For every epoch, find the optimal opacity
## Relation for the Peak Flux and Total Flux
#for eachdict in sorted(resultsdicts):
#    # The Wavelength
#    wave  = eachdict.split('_')[2]
#    epoch = eachdict.split('_')[4]
#    # Introduce a size threshold in case there
#    # was a focus problem
#    if wave == '850':
#        FWHM_cutoff = 20.0 # Arcsec - FROM TESTING IN identify_outliers code
#        source,optimal_ab_peak,run_key_peak,optimal_ab_total,run_key_total = TauRelResults('results/'+eachdict,TransvsPWV850,wave,pix_size,unphys_limit,tau_cutoff,evening_cutoff,morning_cutoff,airmass_cutoff,FWHM_cutoff)
#    else:
#        FWHM_cutoff = 20.0
#        source,optimal_ab_peak,run_key_peak,optimal_ab_total,run_key_total = TauRelResults('results/'+eachdict,TransvsPWV450,wave,pix_size,unphys_limit,tau_cutoff,evening_cutoff,morning_cutoff,airmass_cutoff,FWHM_cutoff)
#
#    print('#####################')
#    print('\nDictionary     : '+eachdict)
#    print('Source            : '+source)
#    print('Optimal Peak (a,b): ('+str(round(optimal_ab_peak[0],2))+','+str(round(optimal_ab_peak[1],5))+')')
#    print('Optimal Peak Key  : '+run_key_peak)
#    print('Optimal Tot. (a,b): ('+str(round(optimal_ab_total[0],2))+','+str(round(optimal_ab_total[1],5))+')')
#    print('Optimal Tot. Key  : '+run_key_total)
#    print('\n')
#    print('#####################')
#
#    # If no observations survived the constraints, all the outputs except for "source" will be set to np.nan
#    if not np.isnan(optimal_ab_peak[0]):
#        if wave=='450':
#            if source not in include_sources_450:
#                include_sources_450.append(source)
#            BINFILES_450.append('results/'+eachdict)
#            BESTKEYS_450_eachsource.append(run_key_peak)
#            EPOCHS_450.append(epoch)
#        else:
#            if source not in include_sources_850:
#                include_sources_850.append(source)
#            BINFILES_850.append('results/'+eachdict)
#            BESTKEYS_850_eachsource.append(run_key_peak)
#            EPOCHS_850.append(epoch)
#
## Now call the "best opacity" relation the one that
## was derived for the largest number of sources in a
## given epoch (based on the peak flux versus transmission
## plots). If there is more than one, take the one that is
## closer to 26,0.012 for 450 and 5.5,0.013 for 850
## as these have shown the best results for each epoch, historically.
#
#BINFILES_450 = np.array(BINFILES_450)
#BINFILES_850 = np.array(BINFILES_850)
#BESTKEYS_450_eachsource = np.array(BESTKEYS_450_eachsource)
#BESTKEYS_850_eachsource = np.array(BESTKEYS_850_eachsource)        
#EPOCHS_450 = np.array(EPOCHS_450)    
#EPOCHS_850 = np.array(EPOCHS_850)
#
#dummy_450_dict = pickle.load(open('results/'+sorted(resultsdicts)[0],'rb'))
#
#BESTKEYS_450 = []
#for eachepoch in EPOCHS_450:
#    print('\n\n 450 Microns\nFor Epoch: '+eachepoch+':')
#    how_many_times_best_450=[]
#    for i in range(len(BESTKEYS_450_eachsource)):
#        how_many_times_best_450.append(len(np.array(BESTKEYS_450_eachsource)[np.where(np.array(BESTKEYS_450_eachsource)==BESTKEYS_450_eachsource[i])]))
#    how_many_times_best_450=np.array(how_many_times_best_450)
#
#    if len(np.where(how_many_times_best_450==max(how_many_times_best_450))[0])>1:
#        BESTKEY_450 = np.array(BESTKEYS_450_eachsource)[np.where(how_many_times_best_450==max(how_many_times_best_450))[0][-1]]
#    else:
#        BESTKEY_450 = np.array(BESTKEYS_450_eachsource)[np.where(how_many_times_best_450==max(how_many_times_best_450))]
#    BESTKEYS_450.append(BESTKEY_450)
#    print('\nOpacity Relation: ',dummy_450_dict[BESTKEY_450]['coeff1'],dummy_450_dict[BESTKEY_450]['coeff2'],'\n\n')
#
#
#dummy_850_dict = pickle.load(open('results/'+sorted(resultsdicts)[-1],'rb'))
#
#BESTKEYS_850 = []
#for eachepoch in EPOCHS_850: 
#    print('\n\n 850 Microns\nFor Epoch: '+eachepoch+':')
#    how_many_times_best_850=[]
#    for i in range(len(BESTKEYS_850_eachsource)):
#        how_many_times_best_850.append(len(np.array(BESTKEYS_850_eachsource)[np.where(np.array(BESTKEYS_850_eachsource)==BESTKEYS_850_eachsource[i])]))
#    how_many_times_best_850=np.array(how_many_times_best_850)
#
#    if len(np.where(how_many_times_best_850==max(how_many_times_best_850))[0])>1:
#        BESTKEY_850 = np.array(BESTKEYS_850_eachsource)[np.where(how_many_times_best_850==max(how_many_times_best_850))[0][-1]]
#    else:
#        BESTKEY_850 = np.array(BESTKEYS_850_eachsource)[np.where(how_many_times_best_850==max(how_many_times_best_850))]
#    BESTKEYS_850.append(BESTKEY_850)
#    print ('\nOpacity Relation: ',dummy_850_dict[BESTKEY_850]['coeff1'],dummy_850_dict[BESTKEY_850]['coeff2'],'\n\n')

# %% [markdown]
# # Determining Significant Differences Between Opacity Relations
#
# You can use `compare_tau_relations.py` to determine if two opacity relations are significantly different to one another. For example:
#
# If the above code tells me that for a give source at 850 microns, the optimal opacity relation is (a,b) = (5.5,0.013) and I wanted to compare that to the nominal (a,b) = 4.6, 0.0043, I would do the following:

# %%
from compare_tau_relations import comparetau

a1 = 5.5
b1 = 0.013

a2 = 4.6
b2 = 0.0043

comparetau(a1,b1,a2,b2)

# %% [markdown]
# This shows you typical grade 1, 2, and 3 weather and the percentage difference this opacity relation would cause in the final FCFs

# %% [markdown]
# # Deriving the FCFs
#
# Now we use `identify_outliers_find_FCFs.py` identify major outliers in the FCF versus MJD plots in order to practically fine tune the weather/time constraints even more (looking at different times of night: early evening, sweet spot, extended observing, and different weather bands - THIS ASSUMES THE OPACITY RELATION IS CONSTANT AT THESE OTHER TIMES/TEMPERATURES) and to derive the final FCFs and their associated uncertainties.

# %%
import glob

for eachresultsfile in sorted(glob.glob('results/*bin')):
    print(eachresultsfile)
# Out:
# results/TauRelPipeline_FullResults_450_Arp220_20110501_201812201521.bin
# results/TauRelPipeline_FullResults_450_Arp220_20120601_201812201549.bin
# results/TauRelPipeline_FullResults_450_Arp220_20140101_201812201614.bin
# results/TauRelPipeline_FullResults_450_Arp220_20150127_201812261115.bin
# results/TauRelPipeline_FullResults_450_Arp220_20150410_201812201807.bin
# results/TauRelPipeline_FullResults_450_Arp220_20161101_201812201915.bin
# results/TauRelPipeline_FullResults_450_Arp220_20171206_201812201959.bin
# results/TauRelPipeline_FullResults_450_Arp220_20180111_201812202006.bin
# results/TauRelPipeline_FullResults_450_Arp220_20180501_201812202024.bin
# results/TauRelPipeline_FullResults_450_Arp220_20180630_201812202037.bin
# results/TauRelPipeline_FullResults_450_Arp220_20180724_201812202046.bin
# results/TauRelPipeline_FullResults_450_Arp220_20181126_201908191344.bin
# results/TauRelPipeline_FullResults_450_Arp220_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_450_Arp220_20181126_201908191453.bin
# results/TauRelPipeline_FullResults_450_Arp220_20181126_201908191458.bin
# results/TauRelPipeline_FullResults_450_Arp220_20181126_201908191508.bin
# results/TauRelPipeline_FullResults_450_Arp220_20181126_201908191523.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20110501_201804231311.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20120601_201804231834.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20140101_201804232204.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20150127_201812261106.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20150410_201804241613.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20161101_201804250313.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20171206_201804250836.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20180111_201804301344.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20180501_201807051631.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20180630_201807161115.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20180630_201807190859.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20180630_201807250954.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20180724_201811280935.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20181126_201908191344.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20181126_201908191453.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20181126_201908191457.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20181126_201908191507.bin
# results/TauRelPipeline_FullResults_450_CRL2688_20181126_201908191523.bin
# results/TauRelPipeline_FullResults_450_CRL618_20110501_201804231331.bin
# results/TauRelPipeline_FullResults_450_CRL618_20120601_201804231947.bin
# results/TauRelPipeline_FullResults_450_CRL618_20140101_201804232300.bin
# results/TauRelPipeline_FullResults_450_CRL618_20150127_201812261108.bin
# results/TauRelPipeline_FullResults_450_CRL618_20150410_201804241702.bin
# results/TauRelPipeline_FullResults_450_CRL618_20161101_201804250350.bin
# results/TauRelPipeline_FullResults_450_CRL618_20171206_201804250841.bin
# results/TauRelPipeline_FullResults_450_CRL618_20180111_201804301357.bin
# results/TauRelPipeline_FullResults_450_CRL618_20180501_201807051633.bin
# results/TauRelPipeline_FullResults_450_CRL618_20180630_201807161117.bin
# results/TauRelPipeline_FullResults_450_CRL618_20180630_201807250957.bin
# results/TauRelPipeline_FullResults_450_CRL618_20180724_201811280954.bin
# results/TauRelPipeline_FullResults_450_CRL618_20181126_201908191344.bin
# results/TauRelPipeline_FullResults_450_CRL618_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_450_CRL618_20181126_201908191453.bin
# results/TauRelPipeline_FullResults_450_CRL618_20181126_201908191457.bin
# results/TauRelPipeline_FullResults_450_CRL618_20181126_201908191507.bin
# results/TauRelPipeline_FullResults_450_CRL618_20181126_201908191523.bin
# results/TauRelPipeline_FullResults_450_MARS_20110501_201804231415.bin
# results/TauRelPipeline_FullResults_450_MARS_20120601_201804232115.bin
# results/TauRelPipeline_FullResults_450_MARS_20140101_201804240031.bin
# results/TauRelPipeline_FullResults_450_MARS_20150127_201812261111.bin
# results/TauRelPipeline_FullResults_450_MARS_20150410_201804241844.bin
# results/TauRelPipeline_FullResults_450_MARS_20161101_201804250421.bin
# results/TauRelPipeline_FullResults_450_MARS_20171206_201804250850.bin
# results/TauRelPipeline_FullResults_450_MARS_20180111_201804301414.bin
# results/TauRelPipeline_FullResults_450_MARS_20180501_201807051641.bin
# results/TauRelPipeline_FullResults_450_MARS_20180630_201807161124.bin
# results/TauRelPipeline_FullResults_450_MARS_20180630_201807251007.bin
# results/TauRelPipeline_FullResults_450_MARS_20180724_201811281006.bin
# results/TauRelPipeline_FullResults_450_MARS_20181126_201908191344.bin
# results/TauRelPipeline_FullResults_450_MARS_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_450_MARS_20181126_201908191453.bin
# results/TauRelPipeline_FullResults_450_MARS_20181126_201908191457.bin
# results/TauRelPipeline_FullResults_450_MARS_20181126_201908191508.bin
# results/TauRelPipeline_FullResults_450_MARS_20181126_201908191523.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20110501_201807021059.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20120601_201807021117.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20140101_201807021131.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20150127_201812261113.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20150410_201807021214.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20161101_201807021240.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20171206_201807021252.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20180111_201807021256.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20180501_201807051643.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20180630_201807161126.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20180630_201807251045.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20180724_201811281009.bin
# results/TauRelPipeline_FullResults_450_NEPTUNE_20181126_201908191334.bin
# results/TauRelPipeline_FullResults_450_URANUS_20110501_201804231342.bin
# results/TauRelPipeline_FullResults_450_URANUS_20120601_201804232052.bin
# results/TauRelPipeline_FullResults_450_URANUS_20140101_201804232357.bin
# results/TauRelPipeline_FullResults_450_URANUS_20150127_201812261110.bin
# results/TauRelPipeline_FullResults_450_URANUS_20150410_201804241754.bin
# results/TauRelPipeline_FullResults_450_URANUS_20161101_201804250415.bin
# results/TauRelPipeline_FullResults_450_URANUS_20171206_201804250847.bin
# results/TauRelPipeline_FullResults_450_URANUS_20180111_201804301402.bin
# results/TauRelPipeline_FullResults_450_URANUS_20180501_201807051635.bin
# results/TauRelPipeline_FullResults_450_URANUS_20180630_201807161119.bin
# results/TauRelPipeline_FullResults_450_URANUS_20180630_201807251000.bin
# results/TauRelPipeline_FullResults_450_URANUS_20180724_201811281003.bin
# results/TauRelPipeline_FullResults_450_URANUS_20181126_201908191344.bin
# results/TauRelPipeline_FullResults_450_URANUS_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_450_URANUS_20181126_201908191453.bin
# results/TauRelPipeline_FullResults_450_URANUS_20181126_201908191457.bin
# results/TauRelPipeline_FullResults_450_URANUS_20181126_201908191507.bin
# results/TauRelPipeline_FullResults_450_URANUS_20181126_201908191523.bin
# results/TauRelPipeline_FullResults_850_Arp220_20110501_201812201523.bin
# results/TauRelPipeline_FullResults_850_Arp220_20120601_201812201704.bin
# results/TauRelPipeline_FullResults_850_Arp220_20140101_201812201741.bin
# results/TauRelPipeline_FullResults_850_Arp220_20150127_201812201744.bin
# results/TauRelPipeline_FullResults_850_Arp220_20150127_201812261119.bin
# results/TauRelPipeline_FullResults_850_Arp220_20150410_201812201850.bin
# results/TauRelPipeline_FullResults_850_Arp220_20161101_201812201957.bin
# results/TauRelPipeline_FullResults_850_Arp220_20171206_201812201959.bin
# results/TauRelPipeline_FullResults_850_Arp220_20180111_201812202018.bin
# results/TauRelPipeline_FullResults_850_Arp220_20180501_201812202033.bin
# results/TauRelPipeline_FullResults_850_Arp220_20180630_201812202042.bin
# results/TauRelPipeline_FullResults_850_Arp220_20180724_201812202050.bin
# results/TauRelPipeline_FullResults_850_Arp220_20181126_201908191345.bin
# results/TauRelPipeline_FullResults_850_Arp220_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_850_Arp220_20181126_201908191508.bin
# results/TauRelPipeline_FullResults_850_Arp220_20181126_201908191527.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20110501_201804231457.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20120601_201804240251.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20140101_201804240945.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20150127_201812261116.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20150410_201804242101.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20161101_201804250607.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20171206_201804250852.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20180111_201804301419.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20180501_201807051706.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20180630_201807161138.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20180630_201807190917.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20180630_201807251117.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20180724_201811281102.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20181126_201908191344.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20181126_201908191453.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20181126_201908191458.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20181126_201908191508.bin
# results/TauRelPipeline_FullResults_850_CRL2688_20181126_201908191526.bin
# results/TauRelPipeline_FullResults_850_CRL618_20110501_201804231538.bin
# results/TauRelPipeline_FullResults_850_CRL618_20120601_201804240450.bin
# results/TauRelPipeline_FullResults_850_CRL618_20140101_201804241135.bin
# results/TauRelPipeline_FullResults_850_CRL618_20150127_201812261117.bin
# results/TauRelPipeline_FullResults_850_CRL618_20150410_201804242231.bin
# results/TauRelPipeline_FullResults_850_CRL618_20161101_201804250717.bin
# results/TauRelPipeline_FullResults_850_CRL618_20171206_201804250902.bin
# results/TauRelPipeline_FullResults_850_CRL618_20180111_201804301436.bin
# results/TauRelPipeline_FullResults_850_CRL618_20180501_201807051707.bin
# results/TauRelPipeline_FullResults_850_CRL618_20180630_201807161140.bin
# results/TauRelPipeline_FullResults_850_CRL618_20180630_201807251120.bin
# results/TauRelPipeline_FullResults_850_CRL618_20180724_201811281136.bin
# results/TauRelPipeline_FullResults_850_CRL618_20181126_201908191344.bin
# results/TauRelPipeline_FullResults_850_CRL618_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_850_CRL618_20181126_201908191453.bin
# results/TauRelPipeline_FullResults_850_CRL618_20181126_201908191508.bin
# results/TauRelPipeline_FullResults_850_CRL618_20181126_201908191526.bin
# results/TauRelPipeline_FullResults_850_MARS_20110501_201804231715.bin
# results/TauRelPipeline_FullResults_850_MARS_20120601_201804240814.bin
# results/TauRelPipeline_FullResults_850_MARS_20140101_201804241505.bin
# results/TauRelPipeline_FullResults_850_MARS_20150127_201812261118.bin
# results/TauRelPipeline_FullResults_850_MARS_20150410_201804250217.bin
# results/TauRelPipeline_FullResults_850_MARS_20161101_201804250833.bin
# results/TauRelPipeline_FullResults_850_MARS_20171206_201804250919.bin
# results/TauRelPipeline_FullResults_850_MARS_20180111_201804301458.bin
# results/TauRelPipeline_FullResults_850_MARS_20180501_201807051719.bin
# results/TauRelPipeline_FullResults_850_MARS_20180630_201807161147.bin
# results/TauRelPipeline_FullResults_850_MARS_20180630_201807251138.bin
# results/TauRelPipeline_FullResults_850_MARS_20180724_201811281201.bin
# results/TauRelPipeline_FullResults_850_MARS_20181126_201908191345.bin
# results/TauRelPipeline_FullResults_850_MARS_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_850_MARS_20181126_201908191453.bin
# results/TauRelPipeline_FullResults_850_MARS_20181126_201908191508.bin
# results/TauRelPipeline_FullResults_850_MARS_20181126_201908191527.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20110501_201807021104.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20120601_201807021143.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20140101_201807021155.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20150127_201812261119.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20150410_201807021230.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20161101_201807021249.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20171206_201807021252.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20180111_201807021258.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20180501_201807051721.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20180630_201807161149.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20180630_201807251141.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20180724_201811281204.bin
# results/TauRelPipeline_FullResults_850_NEPTUNE_20181126_201908150136.bin
# results/TauRelPipeline_FullResults_850_URANUS_20110501_201804231610.bin
# results/TauRelPipeline_FullResults_850_URANUS_20120601_201804240727.bin
# results/TauRelPipeline_FullResults_850_URANUS_20140101_201804241405.bin
# results/TauRelPipeline_FullResults_850_URANUS_20150127_201812261118.bin
# results/TauRelPipeline_FullResults_850_URANUS_20150410_201804250043.bin
# results/TauRelPipeline_FullResults_850_URANUS_20161101_201804250822.bin
# results/TauRelPipeline_FullResults_850_URANUS_20171206_201804250915.bin
# results/TauRelPipeline_FullResults_850_URANUS_20180111_201804301440.bin
# results/TauRelPipeline_FullResults_850_URANUS_20180501_201807051710.bin
# results/TauRelPipeline_FullResults_850_URANUS_20180630_201807161142.bin
# results/TauRelPipeline_FullResults_850_URANUS_20180630_201807251127.bin
# results/TauRelPipeline_FullResults_850_URANUS_20180724_201811281159.bin
# results/TauRelPipeline_FullResults_850_URANUS_20181126_201908191345.bin
# results/TauRelPipeline_FullResults_850_URANUS_20181126_201908191445.bin
# results/TauRelPipeline_FullResults_850_URANUS_20181126_201908191453.bin
# results/TauRelPipeline_FullResults_850_URANUS_20181126_201908191508.bin
# results/TauRelPipeline_FullResults_850_URANUS_20181126_201908191527.bin

# %% [markdown]
# Now, you can use this list of results directories along with the printed output of the TauRelResults() function (namely, the optimal, or, "best" dictionary keys), above, to change the find_outliers() input manually, or just use the automated results depending on what you want to look at. Also, you can play with the constraints and look at all the output images to identify the most optimal constraints to use! Information will be printed about the Beam_FWHM for each source and the sources together (if multiple sources are being analysed). The first plots show all identify outliers in the FCF versus MJD plots and colour those points differently in histograms of source properties so it is easy to see if certain properties (high airmass, low air temperature) bias the results. The final plots show the FCFs as a function of MJD and as a function of transmission and a printout of the FCF for each source in each epoch.
#
# The identify_outliers_find_FCFs_make_catalogue code also produces a topcat readable catalogue of all the measured, calculated, and metadata values so you can plot any parameter against any other parameter.

# %%
#Use this to define  BINFILES and BESTKEYS arrays (already done, below, so this is commented out)

#print('BINFILES_450 = ',list(BINFILES_450))
#print('BESTKEYS_450 = ',list(BESTKEYS_450))
#print('BINFILES_850 = ',list(BINFILES_850))
#print('BESTKEYS_850 = ',list(BESTKEYS_850))

# %%
# Note that is is possible to run the above command on a wider array of data by adding more binfiles and bestkeys
# while changing the contstraints. Just because we couldn't determine a best opacity relation based on strict constraints
# doesn't mean we can't look at the FCF results assuming an opacity relation for some subset of data

# %% [markdown]
# # Now let's make catalogues of all information for easy plotting later:

# %%
# 850 Microns!!! NEW OPACITY RELATION

#from identify_outliers_find_FCFs_make_catalogue import find_outliers

from make_master_cats import make_cats
import os

# If you are manually running the find_outliers command:
include_sources_850 = ['CRL618','URANUS','CRL2688', 'MARS', 'NEPTUNE', 'Arp220']

BINFILES_850 = ['results/TauRelPipeline_FullResults_850_CRL2688_20110501_201804231457.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20110501_201804231538.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20110501_201804231610.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20110501_201804231715.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20110501_201807021104.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20110501_201812201523.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20120601_201804240251.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20120601_201804240450.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20120601_201804240727.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20120601_201804240814.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20120601_201807021143.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20120601_201812201704.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20140101_201804240945.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20140101_201804241135.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20140101_201804241405.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20140101_201804241505.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20140101_201807021155.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20140101_201812201741.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20150127_201812261116.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20150127_201812261117.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20150127_201812261118.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20150127_201812261118.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20150127_201812261119.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20150127_201812261119.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20150410_201804242101.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20150410_201804242231.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20150410_201804250043.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20150410_201804250217.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20150410_201807021230.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20150410_201812201850.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20161101_201804250607.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20161101_201804250717.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20161101_201804250822.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20161101_201804250833.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20161101_201807021249.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20161101_201812201957.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20171206_201804250852.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20171206_201804250902.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20171206_201804250915.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20171206_201804250919.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20171206_201807021252.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20171206_201812201959.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20180111_201804301419.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20180111_201804301436.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20180111_201804301440.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20180111_201804301458.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20180111_201807021258.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20180111_201812202018.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20180501_201807051706.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20180501_201807051707.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20180501_201807051710.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20180501_201807051719.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20180501_201807051721.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20180501_201812202033.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20180630_201807251117.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20180630_201807251120.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20180630_201807251127.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20180630_201807251138.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20180630_201807251141.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20180630_201812202042.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20180724_201811281102.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20180724_201811281136.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20180724_201811281159.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20180724_201811281201.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20180724_201811281204.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20180724_201812202050.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20181126_201908192038.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20181126_201908192204.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20181126_201908192235.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20181126_201908192307.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20181126_201908150136.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20181126_201908200030.bin']

BESTKEYS_850 = ['Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',\
                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',\
                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',\
                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',\
                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',\
                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',\
                'Run_1']

make_cats(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,\
          UPPERTAULIM=0.32,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,\
          INCLUDESOURCES=include_sources_850,aperture_diam=60.0)

os.system('rm -rf tmpADAM*')
# Out:
# 20110501: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20110501: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20110501: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20110501: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20110501: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20110501: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20120601: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20120601: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20120601: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20120601: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20120601: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20120601: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20140101: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20140101: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20140101: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20140101: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20140101: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20140101: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150127: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150127: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150127: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150127: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150127: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150127: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150410: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150410: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150410: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150410: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150410: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20150410: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20161101: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20161101: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20161101: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20161101: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20161101: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20161101: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20171206: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20171206: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20171206: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20171206: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20171206: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20171206: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180111: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180111: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180111: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180111: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180111: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180111: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180501: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180501: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180501: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180501: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180501: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180501: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180630: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180630: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180630: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180630: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180630: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180630: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180724: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180724: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180724: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180724: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180724: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20180724: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20181126: OPACITY RELATION (CRL2688): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20181126: OPACITY RELATION (CRL618): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20181126: OPACITY RELATION (URANUS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20181126: OPACITY RELATION (MARS): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20181126: OPACITY RELATION (NEPTUNE): tau_850 = 5.5(tau225 - 0.013) x Airmass
#
# 20181126: OPACITY RELATION (Arp220): tau_850 = 5.5(tau225 - 0.013) x Airmass
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-d697168d54c6> in <module>()
#      13 BESTKEYS_850 = ['Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',                'Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1','Run_1',                'Run_1']
#      14
# ---> 15 make_cats(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,          UPPERTAULIM=0.32,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,          INCLUDESOURCES=include_sources_850,aperture_diam=60.0)
#      16
#      17 os.system('rm -rf tmpADAM*')
#
# /export/data/smairs/smairs_github/FCFAnalysis/scripts/make_master_cats.py in make_cats(BINFILES, BESTKEYS, OBSSTLIM, OBSENLIM, LOWERTAULIM, UPPERTAULIM, wavelength, FWHMLIM, AMLIM, PIX_SIZE, present_epoch, present_epoch_only, INCLUDESOURCES, aperture_diam)
#     479     for eachfile in range(len(ATSTART)):
#     480
# --> 481         catalogue_file.write(str(sourceind[eachfile])+'\t'+str(sourceindID[eachfile])+'\t'+str(UTDATE[eachfile])+'\t'+str(OBSNUM[eachfile])+'\t'+str(peakfluxes[eachfile])+'\t'+str(peakfluxes_norm[eachfile])+'\t'+str(totalfluxes[eachfile])+'\t'+str(totalfluxes_norm[eachfile])+'\t'+str(FWHM1s[eachfile])+'\t'+str(FWHM2s[eachfile])+'\t'+str(areas[eachfile])+'\t'+str(peak_fcfs[eachfile])+'\t'+str(arcsec_fcfs[eachfile])+'\t'+str(trans_witham[eachfile])+'\t'+str(zentrans[eachfile])+'\t'+str(MJD_OBS[eachfile])+'\t'+str(MJD_END[eachfile])+'\t'+str(OBSST[eachfile])+'\t'+str(OBSEN[eachfile])+'\t'+str(AMSTART[eachfile])+'\t'+str(AMEND[eachfile])+'\t'+str(ATSTART[eachfile])+'\t'+str(ATEND[eachfile])+'\t'+str(FRLEGTST[eachfile])+'\t'+str(FRLEGTEN[eachfile])+'\t'+str(BKLEGTST[eachfile])+'\t'+str(BKLEGTEN[eachfile])+'\t'+str(AZSTART[eachfile])+'\t'+str(AZEND[eachfile])+'\t'+str(ELSTART[eachfile])+'\t'+str(ELEND[eachfile])+'\t'+str(HUMSTART[eachfile])+'\t'+str(HUMEND[eachfile])+'\t'+str(BPSTART[eachfile])+'\t'+str(BPEND[eachfile])+'\t'+str(WNDSPDST[eachfile])+'\t'+str(WNDSPDEN[eachfile])+'\t'+str(WNDDIRST[eachfile])+'\t'+str(WNDDIREN[eachfile])+'\t'+str(TAUST[eachfile])+'\t'+str(TAUEN[eachfile])+'\t'+str(TAUST_T[eachfile])+'\t'+str(TAUEN_T[eachfile])+'\t'+str(TAU225ST[eachfile])+'\t'+str(TAU225EN[eachfile])+'\t'+str(TAUDATST[eachfile])+'\t'+str(TAUDATEN[eachfile])+'\t'+str(SEEINGST[eachfile])+'\t'+str(SEEINGEN[eachfile])+'\t'+str(SEEDATST[eachfile])+'\t'+str(SEEDATEN[eachfile])+'\t'+str(ELAPTIME[eachfile])+'\t'+str(fnames[eachfile])+'\t'+str(delta_trans[eachfile])+'\n')
#     482
#     483     catalogue_file.close()
#
# IndexError: index 13336 is out of bounds for axis 0 with size 13336

# %%
# 450 Microns!!!

#from identify_outliers_find_FCFs_make_catalogue import find_outliers

from make_master_cats import make_cats
import os

# If you are manually running the find_outliers command:
include_sources_450 = ['CRL618','URANUS','CRL2688', 'MARS', 'NEPTUNE','Arp220'] 

BINFILES_450 = ['results/TauRelPipeline_FullResults_450_CRL2688_20110501_201804231311.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20110501_201804231331.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20110501_201804231342.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20110501_201804231415.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20110501_201807021059.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20110501_201812201521.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20120601_201804231834.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20120601_201804231947.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20120601_201804232052.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20120601_201804232115.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20120601_201807021117.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20120601_201812201549.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20140101_201804232204.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20140101_201804232300.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20140101_201804232357.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20140101_201804240031.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20140101_201807021131.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20140101_201812201614.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20150127_201812261106.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20150127_201812261108.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20150127_201812261110.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20150127_201812261111.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20150127_201812261113.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20150127_201812261115.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20150410_201804241613.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20150410_201804241702.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20150410_201804241754.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20150410_201804241844.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20150410_201807021214.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20150410_201812201807.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20161101_201804250313.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20161101_201804250350.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20161101_201804250415.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20161101_201804250421.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20161101_201807021240.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20161101_201812201915.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20171206_201804250836.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20171206_201804250841.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20171206_201804250847.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20171206_201804250850.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20171206_201807021252.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20171206_201812201959.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20180111_201804301344.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20180111_201804301357.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20180111_201804301402.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20180111_201804301414.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20180111_201807021256.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20180111_201812202006.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20180501_201807051631.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20180501_201807051633.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20180501_201807051635.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20180501_201807051641.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20180501_201807051643.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20180501_201812202024.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20180630_201807250954.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20180630_201807250957.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20180630_201807251000.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20180630_201807251007.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20180630_201807251045.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20180630_201812202037.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20180724_201811280935.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20180724_201811280954.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20180724_201811281003.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20180724_201811281006.bin',\
                'results/TauRelPipeline_FullResults_450_NEPTUNE_20180724_201811281009.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20180724_201812202046.bin',\
                'results/TauRelPipeline_FullResults_450_CRL2688_20181126_201908191638.bin',\
                'results/TauRelPipeline_FullResults_450_CRL618_20181126_201908191718.bin',\
                'results/TauRelPipeline_FullResults_450_URANUS_20181126_201908191733.bin',\
                'results/TauRelPipeline_FullResults_450_MARS_20181126_201908191747.bin',\
                'results/TauRelPipeline_FullResults_450_Arp220_20181126_201908191829.bin']

BESTKEYS_450 = ['Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0']

FCF_450_dict = find_outliers(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,\
                             UPPERTAULIM=0.32,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,\
                             INCLUDESOURCES=include_sources_450, aperture_diam=60.0)

os.system('rm -rf tmpADAM*')
# Out:
# 20110501: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20110501: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20110501: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20110501: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20110501: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20110501: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20120601: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20120601: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20120601: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20120601: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20120601: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20120601: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20140101: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20140101: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20140101: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20140101: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20140101: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20140101: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150127: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150127: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150127: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150127: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150127: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150127: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150410: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150410: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150410: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150410: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150410: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20150410: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20161101: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20161101: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20161101: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20161101: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20161101: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20161101: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20171206: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20171206: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20171206: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20171206: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20171206: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20171206: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180111: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180111: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180111: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180111: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180111: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180111: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180501: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180501: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180501: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180501: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180501: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180501: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180630: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180630: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180630: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180630: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180630: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180630: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180724: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180724: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180724: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180724: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180724: OPACITY RELATION (NEPTUNE): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20180724: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20181126: OPACITY RELATION (CRL2688): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20181126: OPACITY RELATION (CRL618): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20181126: OPACITY RELATION (URANUS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20181126: OPACITY RELATION (MARS): tau_450 = 26.0(tau225 - 0.012) x Airmass
#
# 20181126: OPACITY RELATION (Arp220): tau_450 = 26.0(tau225 - 0.012) x Airmass
# #############
#
# CRL618:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  538.8248531753569 +/- 90.83030911960657  =  16.857112025240315
# End Pub. -> Silver WVM Dead, FCF Peak:  445.576102231023 +/- 87.39367882517382  =  19.613636904580176
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  481.2747672762584 +/- 84.80073008037822  =  17.620024120587527
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  521.7810742865489 +/- 89.77389652582346  =  17.20528032730484
# Mem. Rem. -> Mem. Rep., FCF Peak:  597.2152468447571 +/- 101.67758915903059  =  17.025283546630742
# Mem. Rep. -> May SD, FCF Peak:  442.85420497973735 +/- 106.91715082441708  =  24.142742605167097
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  nan +/- -0.0  =  nan
# SMU Fix -> End, FCF Peak:  400.3419115913575 +/- 90.65996453614041  =  22.645634122035194
#
#
# #############
#
# URANUS:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  571.7099453922856 +/- 109.36520921044283  =  19.129492165017453
# End Pub. -> Silver WVM Dead, FCF Peak:  547.248543713735 +/- 87.28227844463636  =  15.949293871541776
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  584.1803432501138 +/- 104.57634015452038  =  17.90137949057053
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  604.6279870090818 +/- 115.04318741180897  =  19.027102595910925
# Mem. Rem. -> Mem. Rep., FCF Peak:  572.9947483836913 +/- 94.65856130593257  =  16.519970134621
# Mem. Rep. -> May SD, FCF Peak:  424.7063262460104 +/- Only 1 data point! No SD can be calculated
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  381.37093010578707 +/- Only 1 data point! No SD can be calculated
# SMU Fix -> End, FCF Peak:  496.720039689765 +/- 83.33623520202109  =  16.777304828303315
#
#
# #############
#
# CRL2688:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  532.6600001037956 +/- 110.95160977466229  =  20.82972435569443
# End Pub. -> Silver WVM Dead, FCF Peak:  551.9058742926888 +/- 95.51936937342344  =  17.307184761502874
# Silver WVM Dead -> Black WVM, FCF Peak:  708.3689428792011 +/- 28.245609695291055  =  3.9874150298692315
# Black WVM -> Filter Ch., FCF Peak:  558.3640020644755 +/- 93.43525007667506  =  16.73375248605047
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  611.0049425703486 +/- 98.18065687093168  =  16.06871729349842
# Mem. Rem. -> Mem. Rep., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rep. -> May SD, FCF Peak:  677.4360469805114 +/- 101.63273882982499  =  15.002558438220927
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  601.8265538603325 +/- 175.24892111462398  =  29.119506274775386
# SMU Fix -> End, FCF Peak:  474.7253386298774 +/- 96.8553425098483  =  20.402395791508862
#
#
# #############
#
# MARS:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  505.5062516300515 +/- 74.76672853874021  =  14.79046565648753
# End Pub. -> Silver WVM Dead, FCF Peak:  563.2826513144399 +/- 79.76191775342566  =  14.160194276762903
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  507.92061501666774 +/- 85.22159574761027  =  16.77852664925082
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rem. -> Mem. Rep., FCF Peak:  605.2439212823292 +/- 0.3583648939867652  =  0.05920999474517615
# Mem. Rep. -> May SD, FCF Peak:  499.6240892346068 +/- 105.0917545243041  =  21.0341648428718
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  406.7307388775536 +/- 99.92239194834511  =  24.567209310045968
# SMU Fix -> End, FCF Peak:  411.36518875879057 +/- 36.89886366997754  =  8.96985566068734
#
#
# #############
#
# NEPTUNE:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  nan +/- -0.0  =  nan
# End Pub. -> Silver WVM Dead, FCF Peak:  nan +/- -0.0  =  nan
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  nan +/- -0.0  =  nan
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rem. -> Mem. Rep., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rep. -> May SD, FCF Peak:  nan +/- -0.0  =  nan
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  nan +/- -0.0  =  nan
# SMU Fix -> End, FCF Peak:  370.7413238997516 +/- 55.38364813746788  =  14.938622852963542
#
#
# #############
#
# Arp220:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  nan +/- -0.0  =  nan
# End Pub. -> Silver WVM Dead, FCF Peak:  nan +/- -0.0  =  nan
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  nan +/- -0.0  =  nan
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rem. -> Mem. Rep., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rep. -> May SD, FCF Peak:  nan +/- -0.0  =  nan
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  nan +/- -0.0  =  nan
# SMU Fix -> End, FCF Peak:  nan +/- -0.0  =  nan
# /local/python/lib/python3.5/site-packages/numpy/lib/function_base.py:356: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /local/python/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# #############
#
# CRL618:
#
#
# Beg. Pub. -> End Pub., FCF Arcsec:  4.496252145551276 +/- 0.7728585161013228  =  17.188949620319043
# End Pub. -> Silver WVM Dead, FCF Arcsec:  3.927403465067144 +/- 0.7356960923818527  =  18.732378756743678
# No data points in this epoch
# Black WVM -> Filter Ch., FCF Arcsec:  3.9668472559805252 +/- 0.789067264095189  =  19.891546439192233
# No data points in this epoch
# New Filters -> Mem. Rem., FCF Arcsec:  4.19895249395692 +/- 0.7781688651782865  =  18.53245223179394
# Mem. Rem. -> Mem. Rep., FCF Arcsec:  4.307328299915991 +/- 0.4297430875112896  =  9.977021893587057
# Mem. Rep. -> May SD, FCF Arcsec:  3.4711725238120086 +/- 0.6839357404300273  =  19.703305892699785
# No data points in this epoch
# No data points in this epoch
# SMU Fix -> End, FCF Arcsec:  3.0682459368397725 +/- 0.7685778281674688  =  25.049420548050573
#
#
# #############
#
# URANUS:
#
#
# Beg. Pub. -> End Pub., FCF Arcsec:  4.862776753222716 +/- 0.7492486680482703  =  15.407836017800312
# End Pub. -> Silver WVM Dead, FCF Arcsec:  4.80702629644513 +/- 0.6165034259025959  =  12.825047917014926
# No data points in this epoch
# Black WVM -> Filter Ch., FCF Arcsec:  4.82198917123068 +/- 0.5708280252303922  =  11.83801964210351
# No data points in this epoch
# New Filters -> Mem. Rem., FCF Arcsec:  4.867703102564412 +/- 0.56842807768474  =  11.6775420708235
# Mem. Rem. -> Mem. Rep., FCF Arcsec:  4.541930398110884 +/- 0.7154833457084349  =  15.752846983432956
# Mem. Rep. -> May SD, FCF Arcsec:  3.7435527082926012 +/- Only 1 data point! No SD can be calculated
# No data points in this epoch
# Post May SD -> SMU Fix, FCF Arcsec:  3.46513331782743 +/- Only 1 data point! No SD can be calculated
# SMU Fix -> End, FCF Arcsec:  3.6529945573519518 +/- 0.4944045867387553  =  13.534227302466833
#
#
# #############
#
# CRL2688:
#
#
# Beg. Pub. -> End Pub., FCF Arcsec:  4.556132155656436 +/- 0.6332584498795018  =  13.899036029789253
# End Pub. -> Silver WVM Dead, FCF Arcsec:  4.769689915757972 +/- 0.7717939804859076  =  16.181219201191166
# Silver WVM Dead -> Black WVM, FCF Arcsec:  4.527097624668606 +/- 0.22633482633069762  =  4.9995570030868475
# Black WVM -> Filter Ch., FCF Arcsec:  4.557346869505176 +/- 0.7441244375172458  =  16.328018446356285
# No data points in this epoch
# New Filters -> Mem. Rem., FCF Arcsec:  4.611803192747402 +/- 0.6082864312851243  =  13.189774278350072
# No data points in this epoch
# Mem. Rep. -> May SD, FCF Arcsec:  5.263169164697649 +/- 1.6110221148729926  =  30.60935463900371
# No data points in this epoch
# Post May SD -> SMU Fix, FCF Arcsec:  4.093037802294859 +/- 0.8453112040386015  =  20.652416246061975
# SMU Fix -> End, FCF Arcsec:  3.601296875378675 +/- 0.6700131163910472  =  18.60477321299971
#
#
# #############
#
# MARS:
#
#
# Beg. Pub. -> End Pub., FCF Arcsec:  4.681479333251579 +/- 0.599155278901543  =  12.798417684894325
# End Pub. -> Silver WVM Dead, FCF Arcsec:  5.079509640043567 +/- 0.5405816312306037  =  10.64239797812387
# No data points in this epoch
# Black WVM -> Filter Ch., FCF Arcsec:  4.326207064426491 +/- 0.4944867891236436  =  11.430030550079458
# No data points in this epoch
# No data points in this epoch
# Mem. Rem. -> Mem. Rep., FCF Arcsec:  5.165925675538082 +/- 0.05998164214843998  =  1.1611015317635653
# Mem. Rep. -> May SD, FCF Arcsec:  4.619693686340555 +/- 0.7834970335005373  =  16.959934720719044
# No data points in this epoch
# Post May SD -> SMU Fix, FCF Arcsec:  3.652357401092251 +/- 0.7442812966313406  =  20.378106929205792
# SMU Fix -> End, FCF Arcsec:  3.7522615970492326 +/- 0.9820732304501127  =  26.17283483705966
#
#
# #############
#
# NEPTUNE:
#
#
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# SMU Fix -> End, FCF Arcsec:  3.1235706341064846 +/- 0.7981575033932738  =  25.552727851841627
#
#
# #############
#
# Arp220:
#
#
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
#
#
#
#
#
# #############
# Epoch: Beg. Pub.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: End Pub.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: Silver WVM Dead
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# /export/data/smairs/smairs_github/FCFAnalysis/scripts/identify_outliers_find_FCFs_full_beta.py:1602: RuntimeWarning: invalid value encountered in sqrt
#   plt.text(np.nanmean(np.array(source_information_dict_by_epoch[eachsource]['FCF_arcsecs_'+str(eachepoch)])[FCF_goodind_for_beamsize])-np.nanstd(np.array(source_information_dict_by_epoch[eachsource]['FCF_arcsecs_'+str(eachepoch)])[FCF_goodind_for_beamsize]),np.nanmean(np.array(source_information_dict_by_epoch[eachsource]['FCF_peaks_'+str(eachepoch)])[FCF_goodind_for_beamsize])+2*np.nanstd(np.array(source_information_dict_by_epoch[eachsource]['FCF_peaks_'+str(eachepoch)])[FCF_goodind_for_beamsize]),eachsource+'\nBeam_eff = '+str(round(np.sqrt(m/1.133),3))+'"',fontsize=15)
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# /export/data/smairs/smairs_github/FCFAnalysis/scripts/identify_outliers_find_FCFs_full_beta.py:1619: RuntimeWarning: invalid value encountered in sqrt
#   plt.text(np.nanmean(np.array(all_FCF_arcsecs_beamsize_thisepoch))-np.nanstd(np.array(all_FCF_arcsecs_beamsize_thisepoch)),np.nanmean(np.array(all_FCF_peaks_beamsize_thisepoch))+2*np.nanstd(np.array(all_FCF_peaks_beamsize_thisepoch)),'Total\nBeam_eff = '+str(round(np.sqrt(m/1.133),3))+'"',fontsize=15)
# #############
# Epoch: Black WVM
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: Filter Ch.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Beam Size Calculated for this Epoch %%%%%%
#
#
# #############
# Epoch: New Filters
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: Mem. Rem.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: Mem. Rep.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: May SD
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Beam Size Calculated for this Epoch %%%%%%
#
#
# #############
# Epoch: Post May SD
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: SMU Fix
# %%%%%% No Data for this source in this Epoch %%%%%%

# %%
# 850 Microns, Nominal Opacity Relation!!!

#from identify_outliers_find_FCFs_make_catalogue import find_outliers

from make_master_cats import make_cats
import os

# If you are manually running the find_outliers command:

include_sources_850 = ['CRL618','URANUS','CRL2688', 'MARS', 'NEPTUNE','Arp220']

BINFILES_850 = ['results/TauRelPipeline_FullResults_850_CRL2688_20110501_201804231457.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20110501_201804231538.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20110501_201804231610.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20110501_201804231715.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20110501_201807021104.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20110501_201812201523.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20120601_201804240251.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20120601_201804240450.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20120601_201804240727.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20120601_201804240814.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20120601_201807021143.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20120601_201812201704.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20140101_201804240945.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20140101_201804241135.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20140101_201804241405.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20140101_201804241505.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20140101_201807021155.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20140101_201812201741.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20150127_201812261116.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20150127_201812261117.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20150127_201812261118.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20150127_201812261118.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20150127_201812261119.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20150127_201812261119.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20150410_201804242101.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20150410_201804242231.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20150410_201804250043.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20150410_201804250217.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20150410_201807021230.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20150410_201812201850.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20161101_201804250607.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20161101_201804250717.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20161101_201804250822.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20161101_201804250833.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20161101_201807021249.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20161101_201812201957.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20171206_201804250852.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20171206_201804250902.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20171206_201804250915.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20171206_201804250919.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20171206_201807021252.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20171206_201812201959.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20180111_201804301419.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20180111_201804301436.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20180111_201804301440.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20180111_201804301458.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20180111_201807021258.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20180111_201812202018.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20180501_201807051706.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20180501_201807051707.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20180501_201807051710.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20180501_201807051719.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20180501_201807051721.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20180501_201812202033.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20180630_201807251117.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20180630_201807251120.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20180630_201807251127.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20180630_201807251138.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20180630_201807251141.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20180630_201812202042.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20180724_201811281102.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20180724_201811281136.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20180724_201811281159.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20180724_201811281201.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20180724_201811281204.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20180724_201812202050.bin',\
                'results/TauRelPipeline_FullResults_850_CRL2688_20181126_201908192038.bin',\
                'results/TauRelPipeline_FullResults_850_CRL618_20181126_201908192204.bin',\
                'results/TauRelPipeline_FullResults_850_URANUS_20181126_201908192235.bin',\
                'results/TauRelPipeline_FullResults_850_MARS_20181126_201908192307.bin',\
                'results/TauRelPipeline_FullResults_850_NEPTUNE_20181126_201908150136.bin',\
                'results/TauRelPipeline_FullResults_850_Arp220_20181126_201908200030.bin']

BESTKEYS_850 = ['Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0',\
                'Run_0']

make_cats(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,\
          UPPERTAULIM=0.32,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,\
          INCLUDESOURCES=include_sources_850,aperture_diam=60.0)

os.system('rm -rf tmpADAM*')
# Out:
# 20110501: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20110501: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20110501: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20110501: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20110501: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20110501: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20120601: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20120601: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20120601: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20120601: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20120601: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20120601: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20140101: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20140101: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20140101: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20140101: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20140101: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20140101: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150127: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150127: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150127: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150127: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150127: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150127: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150410: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150410: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150410: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150410: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150410: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20150410: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20161101: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20161101: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20161101: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20161101: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20161101: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20161101: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20171206: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20171206: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20171206: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20171206: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20171206: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20171206: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180111: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180111: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180111: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180111: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180111: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180111: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180501: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180501: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180501: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180501: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180501: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180501: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180630: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180630: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180630: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180630: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180630: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180630: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180724: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180724: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180724: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180724: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180724: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20180724: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20181126: OPACITY RELATION (CRL2688): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20181126: OPACITY RELATION (CRL618): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20181126: OPACITY RELATION (URANUS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20181126: OPACITY RELATION (MARS): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20181126: OPACITY RELATION (NEPTUNE): tau_850 = 4.6(tau225 - 0.0043) x Airmass
#
# 20181126: OPACITY RELATION (Arp220): tau_850 = 4.6(tau225 - 0.0043) x Airmass
# #############
#
# CRL618:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  542.3248066523437 +/- 28.860635854610187  =  5.3216514348220185
# End Pub. -> Silver WVM Dead, FCF Peak:  520.8054882755592 +/- 37.2361410477548  =  7.149721323223284
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  524.7068912912381 +/- 34.69030550356642  =  6.611368380963687
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  508.21206134366383 +/- 32.751017014468  =  6.444360436444081
# Mem. Rem. -> Mem. Rep., FCF Peak:  483.25405613272267 +/- 23.66282951316246  =  4.896560973026498
# Mem. Rep. -> May SD, FCF Peak:  500.93840312855707 +/- 46.628559984653805  =  9.308242229671379
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  nan +/- -0.0  =  nan
# SMU Fix -> End, FCF Peak:  488.8443777245622 +/- 32.53764696036795  =  6.656033789694352
#
#
# #############
#
# URANUS:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  556.9076341989648 +/- 43.4279538372  =  7.798053244442438
# End Pub. -> Silver WVM Dead, FCF Peak:  533.9039273992865 +/- 31.392138869464915  =  5.879735521403633
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  538.834360524543 +/- 37.22696736489824  =  6.9087961147575365
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  526.0142303221886 +/- 46.00641676018682  =  8.746230445516172
# Mem. Rem. -> Mem. Rep., FCF Peak:  482.041716978823 +/- 28.212964317589673  =  5.852805540236909
# Mem. Rep. -> May SD, FCF Peak:  496.3398145016687 +/- Only 1 data point! No SD can be calculated
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  488.46168632558755 +/- Only 1 data point! No SD can be calculated
# SMU Fix -> End, FCF Peak:  510.2132452487466 +/- 20.39699817645463  =  3.997739840428954
#
#
# #############
#
# CRL2688:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  545.9917172636514 +/- 28.076715101280666  =  5.1423335214667425
# End Pub. -> Silver WVM Dead, FCF Peak:  547.3611336357494 +/- 28.984403025922035  =  5.295297975104346
# Silver WVM Dead -> Black WVM, FCF Peak:  584.7798370827715 +/- 26.20584585938772  =  4.481318300938352
# Black WVM -> Filter Ch., FCF Peak:  559.8308301503192 +/- 39.462315968822814  =  7.048971554179475
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  552.8848647563058 +/- 35.1397672228207  =  6.355711552767718
# Mem. Rem. -> Mem. Rep., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rep. -> May SD, FCF Peak:  548.9633244349509 +/- 26.517209905158115  =  4.830415571468701
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  610.5592552470819 +/- 65.93630283820701  =  10.799329020329703
# SMU Fix -> End, FCF Peak:  531.5140841402549 +/- 43.771293089394796  =  8.235208510080517
#
#
# #############
#
# MARS:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  528.2097815861264 +/- 28.665024236062926  =  5.426825711176081
# End Pub. -> Silver WVM Dead, FCF Peak:  557.4681899349694 +/- 30.588160341237955  =  5.486978610350157
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  547.0691262901271 +/- 36.27230805996165  =  6.630297035026861
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rem. -> Mem. Rep., FCF Peak:  497.46135049873715 +/- 4.109079064239145  =  0.826009711130227
# Mem. Rep. -> May SD, FCF Peak:  526.9071687471326 +/- 35.79137689756269  =  6.792729159989715
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  nan +/- -0.0  =  nan
# SMU Fix -> End, FCF Peak:  nan +/- -0.0  =  nan
#
#
# #############
#
# NEPTUNE:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  nan +/- -0.0  =  nan
# End Pub. -> Silver WVM Dead, FCF Peak:  nan +/- -0.0  =  nan
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  nan +/- -0.0  =  nan
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rem. -> Mem. Rep., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rep. -> May SD, FCF Peak:  nan +/- -0.0  =  nan
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  nan +/- -0.0  =  nan
# SMU Fix -> End, FCF Peak:  539.5238555787212 +/- 24.27651263898008  =  4.499618022068707
#
#
# #############
#
# Arp220:
#
#
# Beg. Pub. -> End Pub., FCF Peak:  nan +/- -0.0  =  nan
# End Pub. -> Silver WVM Dead, FCF Peak:  nan +/- -0.0  =  nan
# Silver WVM Dead -> Black WVM, FCF Peak:  nan +/- -0.0  =  nan
# Black WVM -> Filter Ch., FCF Peak:  nan +/- -0.0  =  nan
# Filter Ch. -> New Filters, FCF Peak:  nan +/- -0.0  =  nan
# New Filters -> Mem. Rem., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rem. -> Mem. Rep., FCF Peak:  nan +/- -0.0  =  nan
# Mem. Rep. -> May SD, FCF Peak:  nan +/- -0.0  =  nan
# May SD -> Post May SD, FCF Peak:  nan +/- -0.0  =  nan
# Post May SD -> SMU Fix, FCF Peak:  nan +/- -0.0  =  nan
# SMU Fix -> End, FCF Peak:  nan +/- -0.0  =  nan
# /local/python/lib/python3.5/site-packages/numpy/lib/function_base.py:356: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /local/python/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# #############
#
# CRL618:
#
#
# Beg. Pub. -> End Pub., FCF Arcsec:  2.3220899142515554 +/- 0.10651021091596244  =  4.586825439543425
# End Pub. -> Silver WVM Dead, FCF Arcsec:  2.230629741487062 +/- 0.09770633711921013  =  4.380213143489858
# No data points in this epoch
# Black WVM -> Filter Ch., FCF Arcsec:  2.1975547850238577 +/- 0.11426670138237045  =  5.199720260040293
# No data points in this epoch
# New Filters -> Mem. Rem., FCF Arcsec:  2.094560036416026 +/- 0.11387828473764529  =  5.436859424306639
# Mem. Rem. -> Mem. Rep., FCF Arcsec:  1.9651951918616701 +/- 0.07311720425528799  =  3.7206077318977435
# Mem. Rep. -> May SD, FCF Arcsec:  2.0495860164109487 +/- 0.12340806073904519  =  6.021121326498232
# No data points in this epoch
# No data points in this epoch
# SMU Fix -> End, FCF Arcsec:  1.9893282925778566 +/- 0.0806807632230531  =  4.055678669230785
#
#
# #############
#
# URANUS:
#
#
# Beg. Pub. -> End Pub., FCF Arcsec:  2.321144017033807 +/- 0.11068973050472805  =  4.768757547675934
# End Pub. -> Silver WVM Dead, FCF Arcsec:  2.287139971329522 +/- 0.06860610937930618  =  2.9996462935945813
# No data points in this epoch
# Black WVM -> Filter Ch., FCF Arcsec:  2.263801355878251 +/- 0.09373157882180143  =  4.140450688326313
# No data points in this epoch
# New Filters -> Mem. Rem., FCF Arcsec:  2.1692734256632025 +/- 0.11295174214307932  =  5.206892815208257
# Mem. Rem. -> Mem. Rep., FCF Arcsec:  2.001076568900215 +/- 0.07988836279214614  =  3.992269163196115
# Mem. Rep. -> May SD, FCF Arcsec:  2.0942035508260246 +/- Only 1 data point! No SD can be calculated
# No data points in this epoch
# Post May SD -> SMU Fix, FCF Arcsec:  2.1179730852562173 +/- Only 1 data point! No SD can be calculated
# SMU Fix -> End, FCF Arcsec:  2.0894641335609063 +/- 0.0820333423139989  =  3.92604692257608
#
#
# #############
#
# CRL2688:
#
#
# Beg. Pub. -> End Pub., FCF Arcsec:  2.2589938225792454 +/- 0.10547296435866339  =  4.669024027619421
# End Pub. -> Silver WVM Dead, FCF Arcsec:  2.288156369924641 +/- 0.081902543486715  =  3.57941199138468
# Silver WVM Dead -> Black WVM, FCF Arcsec:  2.3355034897781164 +/- 0.05606681792780405  =  2.4006308778040255
# Black WVM -> Filter Ch., FCF Arcsec:  2.276239790796738 +/- 0.09209222282762744  =  4.0458049806515755
# No data points in this epoch
# New Filters -> Mem. Rem., FCF Arcsec:  2.1722909005387034 +/- 0.07985456499957704  =  3.6760530083597005
# No data points in this epoch
# Mem. Rep. -> May SD, FCF Arcsec:  2.1213097364749203 +/- 0.1482835973050907  =  6.990190765423087
# No data points in this epoch
# Post May SD -> SMU Fix, FCF Arcsec:  2.1880562581723653 +/- 0.07946764258348596  =  3.6318829685788567
# SMU Fix -> End, FCF Arcsec:  2.11961092043248 +/- 0.10935268131144936  =  5.159092183254902
#
#
# #############
#
# MARS:
#
#
# Beg. Pub. -> End Pub., FCF Arcsec:  2.304194819224645 +/- 0.07403757709381474  =  3.2131648103751997
# End Pub. -> Silver WVM Dead, FCF Arcsec:  2.354968032303554 +/- 0.08333059834356991  =  3.538502315127335
# No data points in this epoch
# Black WVM -> Filter Ch., FCF Arcsec:  2.2562966371122157 +/- 0.09312627303622074  =  4.1273949313424945
# No data points in this epoch
# No data points in this epoch
# Mem. Rem. -> Mem. Rep., FCF Arcsec:  2.1009096467961954 +/- 0.02362010148602437  =  1.1242797386381702
# Mem. Rep. -> May SD, FCF Arcsec:  2.227930067282204 +/- 0.11229122418007068  =  5.040159286375264
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
#
#
# #############
#
# NEPTUNE:
#
#
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# SMU Fix -> End, FCF Arcsec:  2.119724674415086 +/- 0.025796058312076584  =  1.2169532497985716
#
#
# #############
#
# Arp220:
#
#
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
# No data points in this epoch
#
#
#
#
#
# #############
# Epoch: Beg. Pub.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: End Pub.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: Silver WVM Dead
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# /export/data/smairs/smairs_github/FCFAnalysis/scripts/identify_outliers_find_FCFs_full_beta.py:1602: RuntimeWarning: invalid value encountered in sqrt
#   plt.text(np.nanmean(np.array(source_information_dict_by_epoch[eachsource]['FCF_arcsecs_'+str(eachepoch)])[FCF_goodind_for_beamsize])-np.nanstd(np.array(source_information_dict_by_epoch[eachsource]['FCF_arcsecs_'+str(eachepoch)])[FCF_goodind_for_beamsize]),np.nanmean(np.array(source_information_dict_by_epoch[eachsource]['FCF_peaks_'+str(eachepoch)])[FCF_goodind_for_beamsize])+2*np.nanstd(np.array(source_information_dict_by_epoch[eachsource]['FCF_peaks_'+str(eachepoch)])[FCF_goodind_for_beamsize]),eachsource+'\nBeam_eff = '+str(round(np.sqrt(m/1.133),3))+'"',fontsize=15)
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# /export/data/smairs/smairs_github/FCFAnalysis/scripts/identify_outliers_find_FCFs_full_beta.py:1619: RuntimeWarning: invalid value encountered in sqrt
#   plt.text(np.nanmean(np.array(all_FCF_arcsecs_beamsize_thisepoch))-np.nanstd(np.array(all_FCF_arcsecs_beamsize_thisepoch)),np.nanmean(np.array(all_FCF_peaks_beamsize_thisepoch))+2*np.nanstd(np.array(all_FCF_peaks_beamsize_thisepoch)),'Total\nBeam_eff = '+str(round(np.sqrt(m/1.133),3))+'"',fontsize=15)
# #############
# Epoch: Black WVM
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: Filter Ch.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Beam Size Calculated for this Epoch %%%%%%
#
#
# #############
# Epoch: New Filters
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: Mem. Rem.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: Mem. Rep.
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: May SD
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Beam Size Calculated for this Epoch %%%%%%
#
#
# #############
# Epoch: Post May SD
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%
# #############
# Epoch: SMU Fix
# %%%%%% No Data for this source in this Epoch %%%%%%
# %%%%%% No Data for this source in this Epoch %%%%%%

# %%
#Everything Below is Deprecated in Favour of Using the Master Catalogues!

# %%
# You can run the individual results for individual weather grades using this section of code:


# 450 microns
#from identify_outliers_find_FCFs_eachgrade import find_outliers_eachgrade

# If you are manually running the find_outliers command:
#include_sources_450 = ['CRL618','URANUS','CRL2688'] 
#BINFILES_450 = ['results/TauRelPipeline_FullResults_450_CRL2688_20110501_201804231311.bin','results/TauRelPipeline_FullResults_450_CRL618_20110501_201804231331.bin','results/TauRelPipeline_FullResults_450_URANUS_20110501_201804231342.bin','results/TauRelPipeline_FullResults_450_MARS_20110501_201804231415.bin','results/TauRelPipeline_FullResults_450_CRL2688_20120601_201804231834.bin','results/TauRelPipeline_FullResults_450_CRL618_20120601_201804231947.bin','results/TauRelPipeline_FullResults_450_URANUS_20120601_201804232052.bin','results/TauRelPipeline_FullResults_450_MARS_20120601_201804232115.bin','results/TauRelPipeline_FullResults_450_CRL2688_20140101_201804232204.bin','results/TauRelPipeline_FullResults_450_CRL618_20140101_201804232300.bin','results/TauRelPipeline_FullResults_450_URANUS_20140101_201804232357.bin','results/TauRelPipeline_FullResults_450_MARS_20140101_201804240031.bin','results/TauRelPipeline_FullResults_450_CRL2688_20150410_201804241613.bin','results/TauRelPipeline_FullResults_450_CRL618_20150410_201804241702.bin','results/TauRelPipeline_FullResults_450_URANUS_20150410_201804241754.bin','results/TauRelPipeline_FullResults_450_MARS_20150410_201804241844.bin','results/TauRelPipeline_FullResults_450_CRL2688_20161101_201804250313.bin','results/TauRelPipeline_FullResults_450_CRL618_20161101_201804250350.bin','results/TauRelPipeline_FullResults_450_URANUS_20161101_201804250415.bin','results/TauRelPipeline_FullResults_450_MARS_20161101_201804250421.bin','results/TauRelPipeline_FullResults_450_CRL2688_20171206_201804250836.bin','results/TauRelPipeline_FullResults_450_CRL618_20171206_201804250841.bin','results/TauRelPipeline_FullResults_450_URANUS_20171206_201804250847.bin','results/TauRelPipeline_FullResults_450_MARS_20171206_201804250850.bin','results/TauRelPipeline_FullResults_450_CRL2688_20180111_201804250923.bin','results/TauRelPipeline_FullResults_450_CRL618_20180111_201804250933.bin','results/TauRelPipeline_FullResults_450_URANUS_20180111_201804250936.bin','results/TauRelPipeline_FullResults_450_MARS_20180111_201804250945.bin']
#BESTKEYS_450 = ['Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0']

# Grade 1
#FCF_450_dict_B1 = find_outliers_eachgrade(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,UPPERTAULIM=0.05,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# Grade 2
#FCF_450_dict_B2 = find_outliers_eachgrade(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.05,UPPERTAULIM=0.08,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)


# Grade 3
#FCF_450_dict_B3 = find_outliers_eachgrade(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.08,UPPERTAULIM=0.12,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)


# Grade 4
#FCF_450_dict_B4 = find_outliers_eachgrade(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.12,UPPERTAULIM=0.2,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)


# Grade 5
#FCF_450_dict_B5 = find_outliers_eachgrade(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.2,UPPERTAULIM=0.32,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)


# Grades 1, 2, 3
#FCF_450_dict_B123 = find_outliers_eachgrade(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,UPPERTAULIM=0.12,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# Grades 1, 2, 3, 4, 5
#FCF_450_dict_B12345 = find_outliers_eachgrade(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,UPPERTAULIM=0.32,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# %%
# Now, make FCF versus MJD and Beam size plots highlighting different TAU225*airmass bins as colours

# 450 microns
#from identify_outliers_find_FCFs_tautimesairmass import find_outliers_tautimesairmass

# If you are manually running the find_outliers command:
#include_sources_450 = ['CRL618','URANUS','CRL2688'] 
#BINFILES_450 = ['results/TauRelPipeline_FullResults_450_CRL2688_20110501_201804231311.bin','results/TauRelPipeline_FullResults_450_CRL618_20110501_201804231331.bin','results/TauRelPipeline_FullResults_450_URANUS_20110501_201804231342.bin','results/TauRelPipeline_FullResults_450_MARS_20110501_201804231415.bin','results/TauRelPipeline_FullResults_450_CRL2688_20120601_201804231834.bin','results/TauRelPipeline_FullResults_450_CRL618_20120601_201804231947.bin','results/TauRelPipeline_FullResults_450_URANUS_20120601_201804232052.bin','results/TauRelPipeline_FullResults_450_MARS_20120601_201804232115.bin','results/TauRelPipeline_FullResults_450_CRL2688_20140101_201804232204.bin','results/TauRelPipeline_FullResults_450_CRL618_20140101_201804232300.bin','results/TauRelPipeline_FullResults_450_URANUS_20140101_201804232357.bin','results/TauRelPipeline_FullResults_450_MARS_20140101_201804240031.bin','results/TauRelPipeline_FullResults_450_CRL2688_20150410_201804241613.bin','results/TauRelPipeline_FullResults_450_CRL618_20150410_201804241702.bin','results/TauRelPipeline_FullResults_450_URANUS_20150410_201804241754.bin','results/TauRelPipeline_FullResults_450_MARS_20150410_201804241844.bin','results/TauRelPipeline_FullResults_450_CRL2688_20161101_201804250313.bin','results/TauRelPipeline_FullResults_450_CRL618_20161101_201804250350.bin','results/TauRelPipeline_FullResults_450_URANUS_20161101_201804250415.bin','results/TauRelPipeline_FullResults_450_MARS_20161101_201804250421.bin','results/TauRelPipeline_FullResults_450_CRL2688_20171206_201804250836.bin','results/TauRelPipeline_FullResults_450_CRL618_20171206_201804250841.bin','results/TauRelPipeline_FullResults_450_URANUS_20171206_201804250847.bin','results/TauRelPipeline_FullResults_450_MARS_20171206_201804250850.bin','results/TauRelPipeline_FullResults_450_CRL2688_20180111_201804250923.bin','results/TauRelPipeline_FullResults_450_CRL618_20180111_201804250933.bin','results/TauRelPipeline_FullResults_450_URANUS_20180111_201804250936.bin','results/TauRelPipeline_FullResults_450_MARS_20180111_201804250945.bin']
#BESTKEYS_450 = ['Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0','Run_0']

# Grade 1
#FCF_450_dict_B1 = find_outliers_tautimesairmass(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,UPPERTAULIM=0.05,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# Grade 2
#FCF_450_dict_B2 = find_outliers_tautimesairmass(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.05,UPPERTAULIM=0.08,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# Grade 3
#FCF_450_dict_B3 = find_outliers_tautimesairmass(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.08,UPPERTAULIM=0.12,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# Grade 4
#FCF_450_dict_B4 = find_outliers_tautimesairmass(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.12,UPPERTAULIM=0.2,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# Grade 5
#FCF_450_dict_B5 = find_outliers_tautimesairmass(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.2,UPPERTAULIM=0.32,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# Grades 1, 2, 3
#FCF_450_dict_B123 = find_outliers_tautimesairmass(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,UPPERTAULIM=0.12,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# Grades 1, 2, 3
#FCF_450_dict_B12345 = find_outliers_tautimesairmass(BINFILES=BINFILES_450,BESTKEYS=BESTKEYS_450,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,UPPERTAULIM=0.32,wavelength='450',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_450)

# %% [markdown]
# The next cell summarises all the above information in simple plots - only use if you are analysing each weather band individually

# %%
#from FCFs_over_time_eachgrade import FCFs_over_time_eachgrade

#FCFs_over_time_eachgrade([FCF_450_dict_B1,FCF_450_dict_B2,FCF_450_dict_B3,FCF_450_dict_B4,FCF_450_dict_B5,FCF_450_dict_B12345],wave='450')
#FCFs_over_time_eachgrade([FCF_450_dict_B123,FCF_450_dict_B12345],wave='450')

# %% [markdown]
# Same as above but for 850 microns

# %%
# 850 microns
#from identify_outliers_find_FCFs_eachgrade import find_outliers_eachgrade

# If you are manually running the find_outliers command:
#include_sources_850 = ['CRL618','URANUS','CRL2688']
#BINFILES_850 =  ['results/TauRelPipeline_FullResults_850_CRL2688_20110501_201802221936.bin', 'results/TauRelPipeline_FullResults_850_CRL2688_20120601_201802232108.bin', 'results/TauRelPipeline_FullResults_850_CRL2688_20140101_201802240752.bin', 'results/TauRelPipeline_FullResults_850_CRL2688_20150127_201802241553.bin', 'results/TauRelPipeline_FullResults_850_CRL2688_20150410_201802250453.bin', 'results/TauRelPipeline_FullResults_850_CRL2688_20161101_201802271819.bin', 'results/TauRelPipeline_FullResults_850_CRL618_20110501_201802222034.bin', 'results/TauRelPipeline_FullResults_850_CRL618_20120601_201802240016.bin', 'results/TauRelPipeline_FullResults_850_CRL618_20140101_201802241033.bin', 'results/TauRelPipeline_FullResults_850_CRL618_20150410_201802250711.bin', 'results/TauRelPipeline_FullResults_850_CRL618_20161101_201802271959.bin', 'results/TauRelPipeline_FullResults_850_CRL618_20171206_201802272250.bin', 'results/TauRelPipeline_FullResults_850_CRL618_20180111_201802280007.bin', 'results/TauRelPipeline_FullResults_850_MARS_20110501_201802222249.bin', 'results/TauRelPipeline_FullResults_850_MARS_20120601_201802240529.bin', 'results/TauRelPipeline_FullResults_850_MARS_20140101_201802241544.bin', 'results/TauRelPipeline_FullResults_850_MARS_20150410_201802251315.bin', 'results/TauRelPipeline_FullResults_850_MARS_20171206_201802272314.bin', 'results/TauRelPipeline_FullResults_850_URANUS_20110501_201802222121.bin', 'results/TauRelPipeline_FullResults_850_URANUS_20120601_201802240417.bin', 'results/TauRelPipeline_FullResults_850_URANUS_20140101_201802241414.bin', 'results/TauRelPipeline_FullResults_850_URANUS_20150410_201802251048.bin', 'results/TauRelPipeline_FullResults_850_URANUS_20161101_201802272137.bin', 'results/TauRelPipeline_FullResults_850_URANUS_20171206_201802272308.bin']
#BESTKEYS_850 =  ['Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2', 'Run_2']

# Grade 1
#FCF_850_dict_B1 = find_outliers_eachgrade(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,UPPERTAULIM=0.05,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_850)

# Grade 2
#FCF_850_dict_B2 = find_outliers_eachgrade(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.05,UPPERTAULIM=0.08,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_850)

# Grade 3
#FCF_850_dict_B3 = find_outliers_eachgrade(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.08,UPPERTAULIM=0.12,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_850)

# Grade 4
#FCF_850_dict_B4 = find_outliers_eachgrade(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.12,UPPERTAULIM=0.2,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_850)

# Grade 5
#FCF_850_dict_B5 = find_outliers_eachgrade(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.2,UPPERTAULIM=0.32,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_850)

# Grade 1, 2, 3
#FCF_850_dict_B123 = find_outliers_eachgrade(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,UPPERTAULIM=0.12,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_850)

# Grade 1, 2, 3, 4, 5
#FCF_850_dict_B12345 = find_outliers_eachgrade(BINFILES=BINFILES_850,BESTKEYS=BESTKEYS_850,OBSSTLIM=7,OBSENLIM=16,LOWERTAULIM=0.0,UPPERTAULIM=0.32,wavelength='850',FWHMLIM=20.0,AMLIM=1.9,PIX_SIZE=1.0,INCLUDESOURCES=include_sources_850)

# %%
#from FCFs_over_time_eachgrade import FCFs_over_time_eachgrade

#FCFs_over_time_eachgrade([FCF_850_dict_B1,FCF_850_dict_B2,FCF_850_dict_B3,FCF_850_dict_B4,FCF_850_dict_B5,FCF_850_dict_B12345],wave='850')
#FCFs_over_time_eachgrade([FCF_850_dict_B123,FCF_850_dict_B12345],wave='850')

# %% [markdown]
# # Observing Changes over Time
#
# Finally, we use `FCFs_over_time.py` to plot the average FCF for each source along with the (weighted) average FCF over all sources throughout different time regimes. The main regimes I want to look at are:
#
# 1. The 20110501 - 20120601 Era from Dempsey et al. 2013
# 1. The 20120601 - 20150127 Era with the Silver WVM
# 1. The 20150127 - 20150410 Era with no reliable JCMT WVM
# 1. The 20150410 - 20161116 Era with the Black WVM
# 1. The 20161116 - 20171206 Era with the Black WVM and the New Filters
# 1. The 20171206 - 20180111 Era with the removal of the goretex membrane
# 1. The 20180111 - 20180501 Post membrane Replacement to SMU Maintenance
# 1. The 20180501 - 20180630 Post SMU Maintenance to SMU Gain fix (halfway through night of 20180630 - see obs log)
# 1. The 20180630 - Present era.

# %%
#from FCFs_over_time import FCFs_over_time

#FCFs_over_time(FCF_450_dict,wave='450')
#FCFs_over_time(FCF_850_dict,wave='850')
